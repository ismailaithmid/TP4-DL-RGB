# %%
import os
import pandas as pd
import numpy as np
import cv2
from sklearn . model_selection import train_test_split
from sklearn . preprocessing import LabelEncoder , OneHotEncoder
from sklearn . metrics import confusion_matrix ,classification_report
import matplotlib . pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler

# Fonctions d’activation
def relu (x ):
    """
    ReLU activation : max (0 , x)
    """
    assert isinstance (x , np . ndarray ) , " Input to ReLU must be a numpy array "
    result = np . maximum (0 , x)
    assert np . all ( result >= 0) , " ReLU output must be non - negative "
    return result

def relu_derivative ( x) :
    """
    Derivative of ReLU : 1 if x > 0 , else 0
    """
    assert isinstance (x , np . ndarray ) , " Input to ReLU derivative must be a numpy array "
    result = np . where (x > 0 , 1 , 0)
    assert np . all (( result == 0) | ( result == 1) ) , " ReLU derivativemust be 0 or 1"
    return result
    
def softmax ( x):
    """
    Softmax activation : exp (x) / sum ( exp (x))
    """
    assert isinstance (x , np . ndarray ) , " Input to softmax must be a numpy array "
    exp_x = np . exp ( x - np . max ( x , axis =1 , keepdims = True ))

    result = exp_x / np .sum ( exp_x , axis =1 , keepdims = True )
    assert np . all (( result >= 0) & ( result <= 1) ) , " Softmax output must be in [0 , 1]"
    
    assert np . allclose ( np .sum ( result , axis =1) , 1) , " Softmax output sum to 1 per sample "
    
    return result

# %%
# Classe MultiClassNeuralNetwork
class MultiClassNeuralNetwork:
    def __init__(self , layer_sizes , model_optimization,lamda=0.1,learning_rate =0.01):
        """
        Initialize the neural network with given layer sizes and
        learning rate.
        layer_sizes: List of integers [input_size , hidden1_size ,
        ..., output_size]
        """
        assert isinstance(layer_sizes , list) and len(layer_sizes)>= 2, "layer_sizes must be a list with at least 2elements"
        assert all(isinstance(size , int) and size > 0 for size in layer_sizes), "All layer sizes must be positive integers"
        assert isinstance(learning_rate , (int , float)) and learning_rate > 0, "Learning rate must be a positivenumber"

        self.layer_sizes = layer_sizes
        self.learning_rate = learning_rate
        self.weights = []
        self.biases = []
        self.model_optimization=model_optimization
        self.lamda=lamda


        # Initialisation des poids et biais
        np.random.seed (42)
        for i in range(len(layer_sizes) - 1):
            w = np.random.randn(layer_sizes[i], layer_sizes[i+1])* 0.01
            b = np.zeros((1, layer_sizes[i+1]))
            assert w.shape == (layer_sizes[i], layer_sizes[i+1]),f"Weight matrix {i+1} has incorrect shape"
            assert b.shape == (1, layer_sizes[i+1]), f"Bias vector{i+1} has incorrect shape"
            self.weights.append(w)
            self.biases.append(b)
            # Initialisation des variables pour l'optimiseur Adam APRÈS l'initialisation des poids et biais
        self.m_w = [np.zeros_like(w) for w in self.weights]
        self.v_w = [np.zeros_like(w) for w in self.weights]
        self.m_b = [np.zeros_like(b) for b in self.biases]
        self.v_b = [np.zeros_like(b) for b in self.biases]
        self.t = 0 # time step
        self.beta1 = 0.9
        self.beta2 = 0.999
        self.epsilon = 1e-8 # une variable epsilon pour eviter la division sur 0

    def forward(self , X):
        """
        Forward propagation: Z^{[l]} = A^{[l-1]} W^{[l]} + b^{[l]}, A^{[l]} = g(Z^{[l]})
        """
        assert isinstance(X, np.ndarray), "Input X must be a numpy array"
        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"
        self.activations = [X]
        self.z_values = []

        for i in range(len(self.weights) - 1):
            z = np.dot(self.activations[-1],self.weights[i])+self.biases[i]
            assert z.shape == (X.shape[0], self.layer_sizes[i+1]),f"Z^{[i+1]} has incorrect shape"
            self.z_values.append(z)
            self.activations.append(relu(z))

        z=np.dot(self.activations[-1],self.weights[-1])+self.biases[-1]

        assert z.shape == (X.shape[0], self.layer_sizes [-1]), "Output Z has incorrect shape"
        self.z_values.append(z)
        
        output = softmax(z)
        assert output.shape == (X.shape[0], self.layer_sizes [-1]),"Output A has incorrect shape"
        self.activations.append(output)

        return self.activations [-1]

    def compute_loss(self , y_true , y_pred):
        """
        Categorical Cross -Entropy: J = -1/m * sum(y_true * log(y_pred))
        """
        assert isinstance(y_true , np.ndarray) and isinstance(y_pred , np.ndarray), "Inputs to loss must be numpy arrays"

        assert y_true.shape == y_pred.shape , "y_true and y_pred must have the same shape"

        y_pred = np.clip(y_pred , 1e-15, 1 - 1e-15)
        m = y_true . shape [0]

        loss = (-1/m)*np.sum(y_true*np.log(y_pred))
        assert not np.isnan(loss), "Loss computation resulted in NaN"
                             
        return loss 

    def compute_accuracy(self , y_true , y_pred):
        """
        Compute accuracy: proportion of correct predictions
        """
        assert isinstance(y_true , np.ndarray) and isinstance(y_pred , np.ndarray), "Inputs to accuracy must be numpy arrays"

        assert y_true.shape == y_pred.shape , "y_true and y_pred must have the same shape"

        predictions = np.argmax(y_pred , axis =1)

        true_labels = np.argmax(y_true , axis =1)
        accuracy = np.mean(predictions == true_labels)
        assert 0 <= accuracy <= 1, "Accuracy must be between 0 and 1"
        return accuracy

    def backward(self , X, y, outputs):
        """
        Backpropagation: compute dW^{[l]}, db^{[l]} for each layer
        """
        assert isinstance(X, np.ndarray) and isinstance(y, np.ndarray) and isinstance(outputs , np.ndarray), "Inputs to backward must be numpy arrays"

        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"

        assert y.shape == outputs.shape , "y and outputs must have the same shape"

        m = X.shape [0]
        self.d_weights = [ np . zeros_like (w ) for w in self . weights ]
        self.d_biases = [ np . zeros_like ( b) for b in self . biases ]

        dZ = outputs - y # Gradient pour softmax + cross -entropy
       

        
        assert dZ.shape == outputs.shape , "dZ for output layer has incorrect shape"
        self.d_weights [-1] = (self.activations [-2].T @ dZ) / m
        self.d_biases [-1] = np.sum(dZ, axis=0, keepdims=True) / m

        for i in range(len(self.weights) - 2, -1, -1):
            # dZ = np.dot(dZ[i+1],self.weights[i+1].T)*relu_derivative(self.z_values[i])#TODO
            dZ = dZ @ self.weights[i+1].T
            dZ = dZ * relu_derivative(self.z_values[i])
            assert dZ.shape == (X.shape[0], self.layer_sizes[i+1]), f"dZ^{[i+1]} has incorrect shape"
            self.d_weights[i] = (self.activations[i].T @ dZ) / m
            self.d_biases[i] = np.sum(dZ, axis=0, keepdims=True) / m

        # TODO: Ajouter une r gularisation L2 aux gradients des poids

        # dW^{[l]} += lambda * W^{[l]} / m, o lambda est le coefficient de r gularisation
        lamda=self.lamda
        for i in range(len(self.weights)):
            self.d_weights[i]+=lamda*self.weights[i]/m
        

        if self.model_optimization == "SGD":
            # calcule avec gradient descent stochastic
            for i in range (len ( self . weights )) :
              self. weights [ i] -= self . learning_rate * self . d_weights [ i]
              self . biases [ i] -= self . learning_rate * self . d_biases [ i]
        elif self.model_optimization == "Adam":
            # calcule avec Adam
            self.t += 1 # Increment time step per batch
    
            for i in range (len ( self . weights )) :
                # Mise à jour des moments
                self.m_w[i] = self.beta1 * self.m_w[i] + (1 - self.beta1) * self.d_weights[i]
                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * (self.d_weights[i]**2)
                self.m_b[i] = self.beta1 * self.m_b[i] + (1 - self.beta1) * self.d_biases[i]
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * (self.d_biases[i]**2)
    
                # Correctif de biais
                m_w_hat = self.m_w[i] / (1 - self.beta1**self.t)# mise à jour du 1er moment (momentum)
                v_w_hat = self.v_w[i] / (1 - self.beta2**self.t)# mise à jour du 2e moment (RMS)
                m_b_hat = self.m_b[i] / (1 - self.beta1**self.t)# mise à jour du 1er moment (momentum) (sur le biais)
                v_b_hat = self.v_b[i] / (1 - self.beta2**self.t)# mise à jour du 2e moment (RMS)(sur le biais)
    
                # Update des paramètres
                self . weights [ i] -= self . learning_rate  * m_w_hat / (np.sqrt(v_w_hat) + self.epsilon)
                self . biases [ i] -= self . learning_rate  * m_b_hat / (np.sqrt(v_b_hat) + self.epsilon)






    def train(self , X, y, X_val , y_val , epochs , batch_size):
        """
        Train the neural network using mini -batch SGD , with validation
        """
        assert isinstance(X, np.ndarray) and isinstance(y, np.ndarray), "X and y must be numpy arrays"
        assert isinstance(X_val , np.ndarray) and isinstance(y_val ,np.ndarray), "X_val and y_val must be numpy arrays"

        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"
        assert y.shape [1] == self.layer_sizes [-1], f"Output dimension ({y.shape [1]}) must match output layer size({self.layer_sizes [-1]})"
        assert X_val.shape [1] == self.layer_sizes [0], f"Validation input dimension ({X_val.shape [1]}) must match input layer size ({self.layer_sizes [0]})"
        assert y_val.shape [1] == self.layer_sizes [-1], f"Validation output dimension ({y_val.shape [1]}) must match output layer size ({self.layer_sizes [-1]})"
        assert isinstance(epochs , int) and epochs > 0, "Epochs must be a positive integer"
        assert isinstance(batch_size , int) and batch_size > 0, "Batch size must be a positive integer"

        train_losses = []
        val_losses = []
        train_accuracies = []
        val_accuracies = []

        for epoch in range(epochs):
            indices = np.random.permutation(X.shape [0])
            X_shuffled = X[indices]
            y_shuffled = y[indices]

            epoch_loss = 0
            for i in range(0, X.shape[0], batch_size):
                X_batch = X_shuffled[i:i+batch_size]
                y_batch = y_shuffled[i:i+batch_size]

                outputs = self.forward(X_batch)
                epoch_loss += self.compute_loss(y_batch , outputs)
                self.backward(X_batch , y_batch , outputs)

            # Calculer les pertes et accuracies
            train_loss = epoch_loss / (X.shape [0] // batch_size)
            train_pred = self.forward(X)
            train_accuracy = self.compute_accuracy(y, train_pred)
            val_pred = self.forward(X_val)
            val_loss = self.compute_loss(y_val , val_pred)
            val_accuracy = self.compute_accuracy(y_val , val_pred)

            train_losses.append(train_loss)
            val_losses.append(val_loss)
            train_accuracies.append(train_accuracy)
            val_accuracies.append(val_accuracy)

            if epoch % 10 == 0:
                print(f"Epoch {epoch}, Train Loss: {train_loss :.4f}, Val Loss: {val_loss :.4f}, "f"Train Acc: {train_accuracy :.4f}, Val Acc:{val_accuracy :.4f}")

        return train_losses , val_losses , train_accuracies ,val_accuracies

    def predict(self , X):
        """
        Predict class labels
        """
        assert isinstance(X, np.ndarray), "Input X must be a numpy array"
        assert X.shape [1] == self.layer_sizes [0], f"Input dimension ({X.shape [1]}) must match input layer size ({self.layer_sizes [0]})"

        outputs = self.forward(X)
        predictions = np.argmax(outputs , axis =1)
        assert predictions.shape == (X.shape[0],), "Predictions have incorrect shape"
        return predictions

# %%
import os
import sys

# 1) À adapter à vos chemins
latin_labels_txt    = 'C:/Users/yyyiyi/Downloads/AMHCD_64/labels/labels/33-common-latin-tifinagh.txt'
tifinagh_labels_txt = 'C:/Users/yyyiyi/Downloads/AMHCD_64/labels/labels/sorted-33-common-tifinagh.txt'
images_root         = 'C:/Users/yyyiyi/Downloads/AMHCD_64/AMHCD_64/AMHCD_64'
output_csv          = 'C:/Users/yyyiyi/Downloads/AMHCD_64/AMHCD_64/AMHCD_64/new-labels-map.csv'

# 2) Lire les labels Latin et les glyphes Tifinagh
with open(latin_labels_txt, 'r', encoding='utf-8') as f:
    ascii_labels = [line.strip() for line in f if line.strip()]

with open(tifinagh_labels_txt, 'r', encoding='utf-8') as f:
    tif_chars = [line.strip() for line in f if line.strip()]

# 3) Vérification  
if len(ascii_labels) != len(tif_chars):
    print(f"❌ Erreur : {len(ascii_labels)} labels Latin ≠ {len(tif_chars)} glyphes Tifinagh")
    sys.exit(1)

# 4) Génération du CSV
with open(output_csv, 'w', encoding='utf-8', newline='') as out:
    for latin, tif in zip(ascii_labels, tif_chars):
        folder = os.path.join(images_root, latin)
        if not os.path.isdir(folder):
            print(f"⚠️ Dossier introuvable, je passe : {folder}")
            continue
        for fname in sorted(os.listdir(folder)):
            # filtrer si nécessaire par extension d’image
            if not fname.lower().endswith(('.png','.jpg','.jpeg','.bmp','.tif','.tiff')):
                continue
            rel_path = f"./AMHCD_64/AMHCD_64/AMHCD_64/{latin}/{fname}"
            # Écrire UNE ligne contenant chemin + glyphe
            out.write(f"{rel_path},{tif}\n")

print(f"✅ Généré {output_csv} avec {sum(len(os.listdir(os.path.join(images_root,l))) for l in ascii_labels if os.path.isdir(os.path.join(images_root,l)))} entrées.")
# Out:
# ✅ Généré /Users/hicham/Desktop/TP_ben_addi/TP6/images_augmentees/new-labels-map.csv avec 102960 entrées.

# %%
def afficher_images(X,y):
    # 1) Récupérer les labels uniques et un indice représentatif par classe
    labels = np.unique(y)
    indices = [np.where(y == lab)[0][0] for lab in labels]
    
    # 2) Configuration de la grille 3 lignes × 11 colonnes
    rows, cols = 3, 11
    fig, axes = plt.subplots(rows, cols,
                             figsize=(cols * 1.2, rows * 2),
                             constrained_layout=True)
    
    # 3) Affichage des images
    for idx, (lab, img_idx) in enumerate(zip(labels, indices)):
        r, c = divmod(idx, cols)
        ax = axes[r, c]
        img = X[img_idx].reshape(32, 32, 3)
        ax.imshow(img)
        ax.set_title(le.classes_[lab], fontsize=6)
        ax.axis('off')
    
    plt.show()

# %%
import os
import pandas as pd
import numpy as np
import cv2
from pathlib import Path
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# 1) dossier racine
data_dir = 'C:/Users/yyyiyi/Downloads/AMHCD_64/AMHCD_64/AMHCD_64'
csv_path = os.path.join(data_dir, 'new-labels-map.csv')

# 2) lire le CSV (rel_path + glyphe UTF-8)
df = pd.read_csv(
    csv_path,
    header=None,
    names=['rel_path', 'glyph'],
    dtype=str,
    encoding='utf-8'
)

# 3) NORMALISATION des chemins : ne garder que label/filename
def make_full_path(rel_p):
    p = Path(rel_p.lstrip('./'))           # supprime un "./" initial
    sub = p.parts[-2:]                     # ne garder que les 2 derniers segments
    return os.path.join(data_dir, *sub)

df['image_path'] = df['rel_path'].apply(make_full_path)

# 4) vérification d’existence
missing = df.loc[~df['image_path'].apply(os.path.exists), 'image_path']
if not missing.empty:
    raise FileNotFoundError("Fichiers introuvables :\n" + "\n".join(missing.tolist()))
print(f"✅ Chargé {len(df)} images, {df['glyph'].nunique()} classes.")

# 5) encoder les glyphes en entiers
le = LabelEncoder()
df['label_enc'] = le.fit_transform(df['glyph'])
num_classes = len(le.classes_)

# 6) fonction de chargement et prétraitement
def load_and_preprocess(path, target_size=(32,32)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    if img is None:
        raise IOError(f"Impossible de charger : {path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)

    return (img.astype(np.float32) / 255.0).flatten()

# 7) construire X et y

X = np.stack([load_and_preprocess(p) for p in df['image_path']])
y = df['label_enc'].values

afficher_images(X,y)

# 8) split train/val/test
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42
)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42
)

print(f"Train={len(X_train)}, Val={len(X_val)}, Test={len(X_test)}")

# 9) one-hot encoding pour l’entraînement
ohe = OneHotEncoder(sparse_output=False)
y_train_1h = ohe.fit_transform(y_train.reshape(-1,1))
y_val_1h   = ohe.transform(y_val.reshape(-1,1))

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)



# 10) entraîner le modèle
layers = [X_train.shape[1], 64, 32, num_classes]
nn = MultiClassNeuralNetwork(layers, model_optimization="Adam", learning_rate=0.01)
train_losses, val_losses, train_acc, val_acc = nn.train(
    X_train, y_train_1h,
    X_val,   y_val_1h,
    epochs=100, batch_size=64
)

# 11) évaluer sur test
y_pred = nn.predict(X_test)
print("\n=== Classification Report (Test) ===")
print(classification_report(y_test, y_pred, target_names=le.classes_))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Matrice de confusion (Test)')
plt.xlabel('Prédit')
plt.ylabel('Réel')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Courbes de perte et d’accuracy
fig , (ax1 , ax2) = plt.subplots(1, 2, figsize =(12, 5))

# Courbe de perte
ax1.plot(train_losses , label='Train Loss')
ax1.plot(val_losses , label='Validation Loss')
ax1.set_title('Courbe de perte')
ax1.set_xlabel(' poque ')
ax1.set_ylabel('Perte')
ax1.legend ()

# Courbe d’accuracy
ax2.plot(train_acc , label='Train Accuracy ')
ax2.plot(val_acc , label='Validation Accuracy ')
ax2.set_title('Courbe de p r c i s i o n ')
ax2.set_xlabel(' poque ')
ax2.set_ylabel(' P r c i s i o n ')
ax2.legend ()

plt.tight_layout ()
fig.savefig('loss_accuracy_plot.png')
plt.show()
# Out:
# ✅ Chargé 25740 images, 33 classes.
# Train=15444, Val=5148, Test=5148
# Epoch 0, Train Loss: 0.8838, Val Loss: 0.5792, Train Acc: 0.8523, Val Acc:0.8310
# Epoch 10, Train Loss: 0.4429, Val Loss: 0.4499, Train Acc: 0.8866, Val Acc:0.8743
# Epoch 20, Train Loss: 0.4149, Val Loss: 0.4583, Train Acc: 0.8955, Val Acc:0.8726
# Epoch 30, Train Loss: 0.3904, Val Loss: 0.4385, Train Acc: 0.9100, Val Acc:0.8866
# Epoch 40, Train Loss: 0.3868, Val Loss: 0.4453, Train Acc: 0.9038, Val Acc:0.8827
# Epoch 50, Train Loss: 0.3788, Val Loss: 0.4526, Train Acc: 0.8974, Val Acc:0.8803
# Epoch 60, Train Loss: 0.4113, Val Loss: 0.3866, Train Acc: 0.9163, Val Acc:0.8988
# Epoch 70, Train Loss: 0.3845, Val Loss: 0.4699, Train Acc: 0.8909, Val Acc:0.8700
# Epoch 80, Train Loss: 0.3886, Val Loss: 0.4718, Train Acc: 0.9005, Val Acc:0.8728
# Epoch 90, Train Loss: 0.3776, Val Loss: 0.4263, Train Acc: 0.8992, Val Acc:0.8790
#
# === Classification Report (Test) ===
#               precision    recall  f1-score   support
#
#            ⴰ       0.99      1.00      0.99       156
#            ⴱ       0.97      0.90      0.93       156
#            ⴳ       0.91      0.88      0.90       156
#           ⴳⵯ       0.90      0.95      0.92       156
#            ⴷ       0.97      0.87      0.92       156
#            ⴹ       0.81      0.70      0.75       156
#            ⴻ       0.82      0.92      0.87       156
#            ⴼ       0.92      0.92      0.92       156
#            ⴽ       0.87      0.92      0.89       156
#           ⴽⵯ       0.91      0.91      0.91       156
#            ⵀ       0.85      0.91      0.88       156
#            ⵃ       0.90      0.87      0.88       156
#            ⵄ       0.90      0.93      0.91       156
#            ⵅ       0.81      0.87      0.84       156
#            ⵇ       0.95      0.81      0.88       156
#            ⵉ       0.91      0.80      0.85       156
#            ⵊ       0.94      0.95      0.95       156
#            ⵍ       0.95      0.82      0.88       156
#            ⵎ       0.73      0.98      0.84       156
#            ⵏ       0.98      0.93      0.95       156
#            ⵓ       0.95      0.90      0.92       156
#            ⵔ       0.87      0.92      0.89       156
#            ⵕ       0.89      0.92      0.91       156
#            ⵖ       0.92      0.96      0.94       156
#            ⵙ       0.94      0.69      0.80       156
#            ⵚ       0.86      0.92      0.89       156
#            ⵛ       0.93      0.90      0.91       156
#            ⵜ       0.86      0.93      0.90       156
#            ⵟ       0.87      0.83      0.85       156
#            ⵡ       0.94      0.98      0.96       156
#            ⵢ       0.88      0.92      0.90       156
#            ⵣ       0.70      0.83      0.76       156
#            ⵥ       0.73      0.65      0.69       156
#
#     accuracy                           0.88      5148
#    macro avg       0.89      0.88      0.88      5148
# weighted avg       0.89      0.88      0.88      5148

# %%
# ----- Définir les hyperparamètres à tester -----
learning_rates = [0.0001,0.001, 0.01]
batch_sizes    = [ 64,128,256]
n_splits       = 5

# Préparer un tableau pour stocker la performance moyenne (accuracy) pour chaque combinaison
mean_val_accuracy = np.zeros((len(learning_rates), len(batch_sizes)))

# ----- Créer une version one-hot de y_temp pour la CV -----
one_hot_encoder = OneHotEncoder(sparse_output=False)
y_temp_one_hot = one_hot_encoder.fit_transform(y_temp.reshape(-1, 1))
assert y_temp_one_hot.shape[0] == X_temp.shape[0] and y_temp_one_hot.shape[1] == num_classes
# Boucle de recherche par cross-validation sur chaque combinaison de hyperparamètres

scaler = StandardScaler()
# on reshape les vecteurs si nécessaire (ici X_train est shape (n_samples, n_features))
X_temp = scaler.fit_transform(X_temp)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)

for i, lr in enumerate(learning_rates):
    for j, bs in enumerate(batch_sizes):
        print(f"Testing learning_rate={lr}, batch_size={bs} ...")
        kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
        fold_accuracies = []

        for train_index, val_index in kf.split(X_temp):
            X_train_fold = X_temp[train_index]
            X_val_fold   = X_temp[val_index]
            y_train_fold = y_temp_one_hot[train_index]
            y_val_fold   = y_temp_one_hot[val_index]

            # Initialiser un nouveau modèle avec le learning rate courant
            layer_sizes = [X_train_fold.shape[1], 64, 32, num_classes]
            nn = MultiClassNeuralNetwork(layer_sizes, model_optimization="Adam",learning_rate=lr)

            # Entraîner sur ce fold
            _, val_losses, _, val_accs = nn.train(
                X_train_fold, y_train_fold,
                X_val_fold,   y_val_fold,
                epochs=100, batch_size=bs
            )

            # Récupérer la dernière accuracy du fold de validation
            fold_accuracies.append(val_accs[-1])

        # Calculer la moyenne des accuracies sur les n_splits folds
        mean_val_accuracy[i, j] = np.mean(fold_accuracies)
        print(f"→ Moyenne CV accuracy pour lr={lr}, bs={bs} : {mean_val_accuracy[i, j]:.4f}")

# Déterminer la combinaison qui a la performance la plus élevée
best_idx = np.unravel_index(np.argmax(mean_val_accuracy), mean_val_accuracy.shape)
best_lr  = learning_rates[best_idx[0]]
best_bs  = batch_sizes[best_idx[1]]
best_acc = mean_val_accuracy[best_idx]
print(f"\nMeilleure combinaison : learning_rate={best_lr}, batch_size={best_bs} avec CV accuracy={best_acc:.4f}")

# ----- Visualisation des résultats sous forme de heatmap -----
plt.figure(figsize=(8, 6))
sns.heatmap(
    mean_val_accuracy,
    annot=True, fmt=".4f",
    xticklabels=batch_sizes,
    yticklabels=learning_rates,
    cmap="YlGnBu"
)
plt.title("Moyenne CV Accuracy\npour chaque combinaison de learning_rate et batch_size")
plt.xlabel("Batch size")
plt.ylabel("Learning rate")
plt.savefig("cv_accuracy_heatmap.png")
plt.show()

# ----- Réentraîner un modèle final sur tout X_temp avec la meilleure combinaison -----
layer_sizes_final = [X_temp.shape[1], 64, 32, num_classes]
nn_final = MultiClassNeuralNetwork(layer_sizes_final,  model_optimization="Adam",learning_rate=best_lr)
# Reconstruire y_temp_one_hot si nécessaire :
# y_temp_one_hot = one_hot_encoder.fit_transform(y_temp.reshape(-1, 1))
nn_final.train(X_temp, y_temp_one_hot, X_temp, y_temp_one_hot, epochs=100, batch_size=best_bs)

# ----- Évaluer le modèle final sur le jeu de test -----
y_test_pred = nn_final.predict(X_test)
print("\nRapport de classification (Test set) avec la meilleure combinaison :")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Matrice de confusion (Test set)
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title(f"Matrice de confusion (Test set) - lr={best_lr}, bs={best_bs}")
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.savefig("confusion_matrix_best.png")
plt.show()
# Out:
# Testing learning_rate=0.0001, batch_size=64 ...
# Epoch 0, Train Loss: 3.0959, Val Loss: 2.2559, Train Acc: 0.3335, Val Acc:0.3321
# Epoch 10, Train Loss: 0.2789, Val Loss: 0.3312, Train Acc: 0.9361, Val Acc:0.9155
# Epoch 20, Train Loss: 0.1392, Val Loss: 0.2501, Train Acc: 0.9765, Val Acc:0.9357
# Epoch 30, Train Loss: 0.0803, Val Loss: 0.2280, Train Acc: 0.9910, Val Acc:0.9383
# Epoch 40, Train Loss: 0.0497, Val Loss: 0.2176, Train Acc: 0.9970, Val Acc:0.9417
# Epoch 50, Train Loss: 0.0347, Val Loss: 0.2160, Train Acc: 0.9991, Val Acc:0.9422
# Epoch 60, Train Loss: 0.0265, Val Loss: 0.2105, Train Acc: 0.9998, Val Acc:0.9429
# Epoch 70, Train Loss: 0.0223, Val Loss: 0.2082, Train Acc: 0.9999, Val Acc:0.9437
# Epoch 80, Train Loss: 0.0199, Val Loss: 0.2048, Train Acc: 1.0000, Val Acc:0.9456
# Epoch 90, Train Loss: 0.0180, Val Loss: 0.2027, Train Acc: 1.0000, Val Acc:0.9473
# Epoch 0, Train Loss: 3.0767, Val Loss: 2.1956, Train Acc: 0.3573, Val Acc:0.3528
# Epoch 10, Train Loss: 0.2773, Val Loss: 0.3491, Train Acc: 0.9372, Val Acc:0.9022
# Epoch 20, Train Loss: 0.1414, Val Loss: 0.2610, Train Acc: 0.9764, Val Acc:0.9279
# Epoch 30, Train Loss: 0.0796, Val Loss: 0.2340, Train Acc: 0.9920, Val Acc:0.9315
# Epoch 40, Train Loss: 0.0485, Val Loss: 0.2243, Train Acc: 0.9973, Val Acc:0.9352
# Epoch 50, Train Loss: 0.0332, Val Loss: 0.2195, Train Acc: 0.9996, Val Acc:0.9359
# Epoch 60, Train Loss: 0.0254, Val Loss: 0.2173, Train Acc: 0.9998, Val Acc:0.9381
# Epoch 70, Train Loss: 0.0214, Val Loss: 0.2153, Train Acc: 0.9999, Val Acc:0.9393
# Epoch 80, Train Loss: 0.0190, Val Loss: 0.2110, Train Acc: 0.9999, Val Acc:0.9403
# Epoch 90, Train Loss: 0.0175, Val Loss: 0.2140, Train Acc: 1.0000, Val Acc:0.9410
# Epoch 0, Train Loss: 3.1023, Val Loss: 2.2725, Train Acc: 0.3265, Val Acc:0.3254
# Epoch 10, Train Loss: 0.2808, Val Loss: 0.3318, Train Acc: 0.9377, Val Acc:0.9153
# Epoch 20, Train Loss: 0.1446, Val Loss: 0.2499, Train Acc: 0.9753, Val Acc:0.9322
# Epoch 30, Train Loss: 0.0827, Val Loss: 0.2237, Train Acc: 0.9908, Val Acc:0.9381
# Epoch 40, Train Loss: 0.0513, Val Loss: 0.2139, Train Acc: 0.9968, Val Acc:0.9439
# Epoch 50, Train Loss: 0.0354, Val Loss: 0.2084, Train Acc: 0.9987, Val Acc:0.9434
# Epoch 60, Train Loss: 0.0271, Val Loss: 0.2064, Train Acc: 0.9996, Val Acc:0.9458
# Epoch 70, Train Loss: 0.0225, Val Loss: 0.2025, Train Acc: 0.9997, Val Acc:0.9475
# Epoch 80, Train Loss: 0.0203, Val Loss: 0.1979, Train Acc: 0.9999, Val Acc:0.9475
# Epoch 90, Train Loss: 0.0183, Val Loss: 0.1966, Train Acc: 0.9999, Val Acc:0.9463
# Epoch 0, Train Loss: 3.0814, Val Loss: 2.2358, Train Acc: 0.3183, Val Acc:0.2999
# Epoch 10, Train Loss: 0.2790, Val Loss: 0.3321, Train Acc: 0.9365, Val Acc:0.9121
# Epoch 20, Train Loss: 0.1398, Val Loss: 0.2490, Train Acc: 0.9763, Val Acc:0.9364
# Epoch 30, Train Loss: 0.0792, Val Loss: 0.2250, Train Acc: 0.9919, Val Acc:0.9403
# Epoch 40, Train Loss: 0.0485, Val Loss: 0.2140, Train Acc: 0.9973, Val Acc:0.9441
# Epoch 50, Train Loss: 0.0338, Val Loss: 0.2122, Train Acc: 0.9992, Val Acc:0.9437
# Epoch 60, Train Loss: 0.0263, Val Loss: 0.2083, Train Acc: 0.9997, Val Acc:0.9456
# Epoch 70, Train Loss: 0.0218, Val Loss: 0.2074, Train Acc: 0.9999, Val Acc:0.9458
# Epoch 80, Train Loss: 0.0195, Val Loss: 0.2031, Train Acc: 0.9999, Val Acc:0.9454
# Epoch 90, Train Loss: 0.0176, Val Loss: 0.2005, Train Acc: 0.9999, Val Acc:0.9478
# Epoch 0, Train Loss: 3.0763, Val Loss: 2.2965, Train Acc: 0.3093, Val Acc:0.3009
# Epoch 10, Train Loss: 0.2824, Val Loss: 0.3543, Train Acc: 0.9351, Val Acc:0.9038
# Epoch 20, Train Loss: 0.1427, Val Loss: 0.2676, Train Acc: 0.9744, Val Acc:0.9269
# Epoch 30, Train Loss: 0.0801, Val Loss: 0.2452, Train Acc: 0.9916, Val Acc:0.9335
# Epoch 40, Train Loss: 0.0489, Val Loss: 0.2335, Train Acc: 0.9976, Val Acc:0.9359
# Epoch 50, Train Loss: 0.0336, Val Loss: 0.2284, Train Acc: 0.9991, Val Acc:0.9369
# Epoch 60, Train Loss: 0.0263, Val Loss: 0.2299, Train Acc: 0.9996, Val Acc:0.9376
# Epoch 70, Train Loss: 0.0220, Val Loss: 0.2250, Train Acc: 0.9999, Val Acc:0.9381
# Epoch 80, Train Loss: 0.0194, Val Loss: 0.2211, Train Acc: 0.9999, Val Acc:0.9415
# Epoch 90, Train Loss: 0.0178, Val Loss: 0.2179, Train Acc: 0.9999, Val Acc:0.9407
# → Moyenne CV accuracy pour lr=0.0001, bs=64 : 0.9449
# Testing learning_rate=0.0001, batch_size=128 ...
# Epoch 0, Train Loss: 3.4316, Val Loss: 3.0847, Train Acc: 0.1323, Val Acc:0.1340
# Epoch 10, Train Loss: 0.3800, Val Loss: 0.4023, Train Acc: 0.9095, Val Acc:0.8956
# Epoch 20, Train Loss: 0.2000, Val Loss: 0.2780, Train Acc: 0.9549, Val Acc:0.9247
# Epoch 30, Train Loss: 0.1249, Val Loss: 0.2414, Train Acc: 0.9766, Val Acc:0.9349
# Epoch 40, Train Loss: 0.0813, Val Loss: 0.2270, Train Acc: 0.9896, Val Acc:0.9386
# Epoch 50, Train Loss: 0.0542, Val Loss: 0.2200, Train Acc: 0.9945, Val Acc:0.9398
# Epoch 60, Train Loss: 0.0373, Val Loss: 0.2161, Train Acc: 0.9979, Val Acc:0.9422
# Epoch 70, Train Loss: 0.0269, Val Loss: 0.2145, Train Acc: 0.9993, Val Acc:0.9434
# Epoch 80, Train Loss: 0.0203, Val Loss: 0.2138, Train Acc: 0.9998, Val Acc:0.9454
# Epoch 90, Train Loss: 0.0161, Val Loss: 0.2137, Train Acc: 1.0000, Val Acc:0.9454
# Epoch 0, Train Loss: 3.4304, Val Loss: 3.0927, Train Acc: 0.2105, Val Acc:0.2030
# Epoch 10, Train Loss: 0.3751, Val Loss: 0.4212, Train Acc: 0.9072, Val Acc:0.8806
# Epoch 20, Train Loss: 0.2024, Val Loss: 0.2973, Train Acc: 0.9547, Val Acc:0.9172
# Epoch 30, Train Loss: 0.1267, Val Loss: 0.2524, Train Acc: 0.9772, Val Acc:0.9286
# Epoch 40, Train Loss: 0.0821, Val Loss: 0.2357, Train Acc: 0.9887, Val Acc:0.9320
# Epoch 50, Train Loss: 0.0542, Val Loss: 0.2282, Train Acc: 0.9953, Val Acc:0.9330
# Epoch 60, Train Loss: 0.0368, Val Loss: 0.2271, Train Acc: 0.9981, Val Acc:0.9357
# Epoch 70, Train Loss: 0.0263, Val Loss: 0.2266, Train Acc: 0.9996, Val Acc:0.9359
# Epoch 80, Train Loss: 0.0198, Val Loss: 0.2260, Train Acc: 0.9999, Val Acc:0.9371
# Epoch 90, Train Loss: 0.0157, Val Loss: 0.2264, Train Acc: 0.9999, Val Acc:0.9386
# Epoch 0, Train Loss: 3.4250, Val Loss: 3.0851, Train Acc: 0.1357, Val Acc:0.1328
# Epoch 10, Train Loss: 0.3887, Val Loss: 0.4118, Train Acc: 0.9066, Val Acc:0.8924
# Epoch 20, Train Loss: 0.2097, Val Loss: 0.2881, Train Acc: 0.9517, Val Acc:0.9206
# Epoch 30, Train Loss: 0.1321, Val Loss: 0.2470, Train Acc: 0.9743, Val Acc:0.9315
# Epoch 40, Train Loss: 0.0855, Val Loss: 0.2288, Train Acc: 0.9876, Val Acc:0.9381
# Epoch 50, Train Loss: 0.0567, Val Loss: 0.2190, Train Acc: 0.9950, Val Acc:0.9407
# Epoch 60, Train Loss: 0.0387, Val Loss: 0.2184, Train Acc: 0.9979, Val Acc:0.9410
# Epoch 70, Train Loss: 0.0278, Val Loss: 0.2157, Train Acc: 0.9992, Val Acc:0.9444
# Epoch 80, Train Loss: 0.0211, Val Loss: 0.2153, Train Acc: 0.9997, Val Acc:0.9441
# Epoch 90, Train Loss: 0.0167, Val Loss: 0.2156, Train Acc: 0.9999, Val Acc:0.9449
# Epoch 0, Train Loss: 3.4293, Val Loss: 3.0751, Train Acc: 0.1798, Val Acc:0.1744
# Epoch 10, Train Loss: 0.3847, Val Loss: 0.4148, Train Acc: 0.9059, Val Acc:0.8873
# Epoch 20, Train Loss: 0.2040, Val Loss: 0.2874, Train Acc: 0.9534, Val Acc:0.9240
# Epoch 30, Train Loss: 0.1279, Val Loss: 0.2486, Train Acc: 0.9754, Val Acc:0.9364
# Epoch 40, Train Loss: 0.0831, Val Loss: 0.2286, Train Acc: 0.9886, Val Acc:0.9407
# Epoch 50, Train Loss: 0.0549, Val Loss: 0.2203, Train Acc: 0.9950, Val Acc:0.9403
# Epoch 60, Train Loss: 0.0378, Val Loss: 0.2155, Train Acc: 0.9978, Val Acc:0.9441
# Epoch 70, Train Loss: 0.0273, Val Loss: 0.2162, Train Acc: 0.9992, Val Acc:0.9458
# Epoch 80, Train Loss: 0.0208, Val Loss: 0.2160, Train Acc: 0.9998, Val Acc:0.9449
# Epoch 90, Train Loss: 0.0165, Val Loss: 0.2175, Train Acc: 0.9999, Val Acc:0.9463
# Epoch 0, Train Loss: 3.4222, Val Loss: 3.0833, Train Acc: 0.1565, Val Acc:0.1532
# Epoch 10, Train Loss: 0.3790, Val Loss: 0.4242, Train Acc: 0.9082, Val Acc:0.8871
# Epoch 20, Train Loss: 0.2038, Val Loss: 0.3021, Train Acc: 0.9527, Val Acc:0.9153
# Epoch 30, Train Loss: 0.1266, Val Loss: 0.2622, Train Acc: 0.9747, Val Acc:0.9257
# Epoch 40, Train Loss: 0.0809, Val Loss: 0.2446, Train Acc: 0.9888, Val Acc:0.9313
# Epoch 50, Train Loss: 0.0531, Val Loss: 0.2376, Train Acc: 0.9956, Val Acc:0.9352
# Epoch 60, Train Loss: 0.0362, Val Loss: 0.2353, Train Acc: 0.9985, Val Acc:0.9371
# Epoch 70, Train Loss: 0.0260, Val Loss: 0.2344, Train Acc: 0.9992, Val Acc:0.9369
# Epoch 80, Train Loss: 0.0199, Val Loss: 0.2347, Train Acc: 0.9996, Val Acc:0.9383
# Epoch 90, Train Loss: 0.0158, Val Loss: 0.2334, Train Acc: 0.9999, Val Acc:0.9410
# → Moyenne CV accuracy pour lr=0.0001, bs=128 : 0.9435
# Testing learning_rate=0.0001, batch_size=256 ...
# Epoch 0, Train Loss: 3.5356, Val Loss: 3.4358, Train Acc: 0.2180, Val Acc:0.2251
# Epoch 10, Train Loss: 0.5931, Val Loss: 0.5802, Train Acc: 0.8569, Val Acc:0.8424
# Epoch 20, Train Loss: 0.3076, Val Loss: 0.3470, Train Acc: 0.9232, Val Acc:0.9082
# Epoch 30, Train Loss: 0.2028, Val Loss: 0.2776, Train Acc: 0.9522, Val Acc:0.9252
# Epoch 40, Train Loss: 0.1435, Val Loss: 0.2490, Train Acc: 0.9692, Val Acc:0.9337
# Epoch 50, Train Loss: 0.1039, Val Loss: 0.2346, Train Acc: 0.9796, Val Acc:0.9369
# Epoch 60, Train Loss: 0.0767, Val Loss: 0.2278, Train Acc: 0.9880, Val Acc:0.9386
# Epoch 70, Train Loss: 0.0570, Val Loss: 0.2243, Train Acc: 0.9928, Val Acc:0.9383
# Epoch 80, Train Loss: 0.0424, Val Loss: 0.2236, Train Acc: 0.9962, Val Acc:0.9383
# Epoch 90, Train Loss: 0.0321, Val Loss: 0.2239, Train Acc: 0.9981, Val Acc:0.9408
# Epoch 0, Train Loss: 3.5351, Val Loss: 3.4374, Train Acc: 0.2664, Val Acc:0.2571
# Epoch 10, Train Loss: 0.5839, Val Loss: 0.5896, Train Acc: 0.8614, Val Acc:0.8432
# Epoch 20, Train Loss: 0.3065, Val Loss: 0.3706, Train Acc: 0.9228, Val Acc:0.8941
# Epoch 30, Train Loss: 0.2047, Val Loss: 0.2975, Train Acc: 0.9513, Val Acc:0.9133
# Epoch 40, Train Loss: 0.1456, Val Loss: 0.2614, Train Acc: 0.9690, Val Acc:0.9255
# Epoch 50, Train Loss: 0.1064, Val Loss: 0.2430, Train Acc: 0.9801, Val Acc:0.9301
# Epoch 60, Train Loss: 0.0776, Val Loss: 0.2339, Train Acc: 0.9883, Val Acc:0.9315
# Epoch 70, Train Loss: 0.0570, Val Loss: 0.2296, Train Acc: 0.9928, Val Acc:0.9315
# Epoch 80, Train Loss: 0.0423, Val Loss: 0.2306, Train Acc: 0.9958, Val Acc:0.9335
# Epoch 90, Train Loss: 0.0315, Val Loss: 0.2314, Train Acc: 0.9981, Val Acc:0.9361
# Epoch 0, Train Loss: 3.5348, Val Loss: 3.4353, Train Acc: 0.1963, Val Acc:0.1911
# Epoch 10, Train Loss: 0.6013, Val Loss: 0.5893, Train Acc: 0.8547, Val Acc:0.8492
# Epoch 20, Train Loss: 0.3150, Val Loss: 0.3589, Train Acc: 0.9217, Val Acc:0.9036
# Epoch 30, Train Loss: 0.2109, Val Loss: 0.2884, Train Acc: 0.9490, Val Acc:0.9201
# Epoch 40, Train Loss: 0.1508, Val Loss: 0.2553, Train Acc: 0.9661, Val Acc:0.9286
# Epoch 50, Train Loss: 0.1101, Val Loss: 0.2363, Train Acc: 0.9782, Val Acc:0.9361
# Epoch 60, Train Loss: 0.0805, Val Loss: 0.2288, Train Acc: 0.9872, Val Acc:0.9395
# Epoch 70, Train Loss: 0.0596, Val Loss: 0.2236, Train Acc: 0.9929, Val Acc:0.9393
# Epoch 80, Train Loss: 0.0444, Val Loss: 0.2224, Train Acc: 0.9959, Val Acc:0.9390
# Epoch 90, Train Loss: 0.0333, Val Loss: 0.2231, Train Acc: 0.9981, Val Acc:0.9393
# Epoch 0, Train Loss: 3.5356, Val Loss: 3.4378, Train Acc: 0.2636, Val Acc:0.2586
# Epoch 10, Train Loss: 0.5991, Val Loss: 0.5876, Train Acc: 0.8536, Val Acc:0.8412
# Epoch 20, Train Loss: 0.3102, Val Loss: 0.3604, Train Acc: 0.9212, Val Acc:0.9000
# Epoch 30, Train Loss: 0.2039, Val Loss: 0.2905, Train Acc: 0.9509, Val Acc:0.9199
# Epoch 40, Train Loss: 0.1447, Val Loss: 0.2580, Train Acc: 0.9674, Val Acc:0.9320
# Epoch 50, Train Loss: 0.1058, Val Loss: 0.2414, Train Acc: 0.9789, Val Acc:0.9366
# Epoch 60, Train Loss: 0.0770, Val Loss: 0.2323, Train Acc: 0.9883, Val Acc:0.9383
# Epoch 70, Train Loss: 0.0567, Val Loss: 0.2267, Train Acc: 0.9936, Val Acc:0.9400
# Epoch 80, Train Loss: 0.0421, Val Loss: 0.2250, Train Acc: 0.9964, Val Acc:0.9390
# Epoch 90, Train Loss: 0.0317, Val Loss: 0.2254, Train Acc: 0.9980, Val Acc:0.9395
# Epoch 0, Train Loss: 3.5343, Val Loss: 3.4363, Train Acc: 0.2053, Val Acc:0.2003
# Epoch 10, Train Loss: 0.5935, Val Loss: 0.6008, Train Acc: 0.8577, Val Acc:0.8392
# Epoch 20, Train Loss: 0.3073, Val Loss: 0.3745, Train Acc: 0.9218, Val Acc:0.8941
# Epoch 30, Train Loss: 0.2045, Val Loss: 0.3049, Train Acc: 0.9500, Val Acc:0.9126
# Epoch 40, Train Loss: 0.1458, Val Loss: 0.2720, Train Acc: 0.9661, Val Acc:0.9203
# Epoch 50, Train Loss: 0.1054, Val Loss: 0.2567, Train Acc: 0.9783, Val Acc:0.9284
# Epoch 60, Train Loss: 0.0768, Val Loss: 0.2483, Train Acc: 0.9877, Val Acc:0.9327
# Epoch 70, Train Loss: 0.0560, Val Loss: 0.2453, Train Acc: 0.9935, Val Acc:0.9352
# Epoch 80, Train Loss: 0.0410, Val Loss: 0.2434, Train Acc: 0.9970, Val Acc:0.9371
# Epoch 90, Train Loss: 0.0306, Val Loss: 0.2432, Train Acc: 0.9982, Val Acc:0.9352
# → Moyenne CV accuracy pour lr=0.0001, bs=256 : 0.9390
# Testing learning_rate=0.001, batch_size=64 ...
# Epoch 0, Train Loss: 1.1548, Val Loss: 0.3991, Train Acc: 0.9060, Val Acc:0.8908
# Epoch 10, Train Loss: 0.0615, Val Loss: 0.2258, Train Acc: 0.9871, Val Acc:0.9361
# Epoch 20, Train Loss: 0.0398, Val Loss: 0.2344, Train Acc: 0.9904, Val Acc:0.9395
# Epoch 30, Train Loss: 0.0187, Val Loss: 0.1697, Train Acc: 0.9992, Val Acc:0.9558
# Epoch 40, Train Loss: 0.0274, Val Loss: 0.1625, Train Acc: 0.9988, Val Acc:0.9595
# Epoch 50, Train Loss: 0.0223, Val Loss: 0.1663, Train Acc: 0.9989, Val Acc:0.9575
# Epoch 60, Train Loss: 0.0193, Val Loss: 0.1639, Train Acc: 0.9983, Val Acc:0.9556
# Epoch 70, Train Loss: 0.0281, Val Loss: 0.1768, Train Acc: 0.9977, Val Acc:0.9548
# Epoch 80, Train Loss: 0.0653, Val Loss: 0.2102, Train Acc: 0.9887, Val Acc:0.9468
# Epoch 90, Train Loss: 0.0445, Val Loss: 0.2114, Train Acc: 0.9865, Val Acc:0.9439
# Epoch 0, Train Loss: 1.1487, Val Loss: 0.3953, Train Acc: 0.9111, Val Acc:0.8878
# Epoch 10, Train Loss: 0.0608, Val Loss: 0.2308, Train Acc: 0.9865, Val Acc:0.9328
# Epoch 20, Train Loss: 0.0438, Val Loss: 0.2154, Train Acc: 0.9922, Val Acc:0.9371
# Epoch 30, Train Loss: 0.0587, Val Loss: 0.2657, Train Acc: 0.9774, Val Acc:0.9301
# Epoch 40, Train Loss: 0.0556, Val Loss: 0.2348, Train Acc: 0.9818, Val Acc:0.9388
# Epoch 50, Train Loss: 0.0269, Val Loss: 0.1923, Train Acc: 0.9919, Val Acc:0.9425
# Epoch 60, Train Loss: 0.0201, Val Loss: 0.1616, Train Acc: 0.9974, Val Acc:0.9536
# Epoch 70, Train Loss: 0.0223, Val Loss: 0.1663, Train Acc: 0.9988, Val Acc:0.9512
# Epoch 80, Train Loss: 0.0675, Val Loss: 0.1881, Train Acc: 0.9956, Val Acc:0.9468
# Epoch 90, Train Loss: 0.0608, Val Loss: 0.2658, Train Acc: 0.9758, Val Acc:0.9313
# Epoch 0, Train Loss: 1.1137, Val Loss: 0.3942, Train Acc: 0.9114, Val Acc:0.8890
# Epoch 10, Train Loss: 0.0671, Val Loss: 0.2301, Train Acc: 0.9860, Val Acc:0.9352
# Epoch 20, Train Loss: 0.0481, Val Loss: 0.2004, Train Acc: 0.9949, Val Acc:0.9492
# Epoch 30, Train Loss: 0.0704, Val Loss: 0.2202, Train Acc: 0.9900, Val Acc:0.9432
# Epoch 40, Train Loss: 0.0819, Val Loss: 0.2508, Train Acc: 0.9760, Val Acc:0.9325
# Epoch 50, Train Loss: 0.0235, Val Loss: 0.1642, Train Acc: 0.9961, Val Acc:0.9507
# Epoch 60, Train Loss: 0.0212, Val Loss: 0.1994, Train Acc: 0.9949, Val Acc:0.9473
# Epoch 70, Train Loss: 0.0698, Val Loss: 0.1941, Train Acc: 0.9911, Val Acc:0.9517
# Epoch 80, Train Loss: 0.0273, Val Loss: 0.1662, Train Acc: 0.9954, Val Acc:0.9512
# Epoch 90, Train Loss: 0.0156, Val Loss: 0.1500, Train Acc: 0.9988, Val Acc:0.9573
# Epoch 0, Train Loss: 1.2302, Val Loss: 0.4357, Train Acc: 0.8950, Val Acc:0.8822
# Epoch 10, Train Loss: 0.0674, Val Loss: 0.2152, Train Acc: 0.9846, Val Acc:0.9393
# Epoch 20, Train Loss: 0.0385, Val Loss: 0.1857, Train Acc: 0.9963, Val Acc:0.9517
# Epoch 30, Train Loss: 0.0389, Val Loss: 0.1758, Train Acc: 0.9956, Val Acc:0.9551
# Epoch 40, Train Loss: 0.0461, Val Loss: 0.2079, Train Acc: 0.9885, Val Acc:0.9434
# Epoch 50, Train Loss: 0.0202, Val Loss: 0.1657, Train Acc: 0.9969, Val Acc:0.9546
# Epoch 60, Train Loss: 0.0268, Val Loss: 0.1899, Train Acc: 0.9962, Val Acc:0.9529
# Epoch 70, Train Loss: 0.0630, Val Loss: 0.1768, Train Acc: 0.9935, Val Acc:0.9541
# Epoch 80, Train Loss: 0.0368, Val Loss: 0.2237, Train Acc: 0.9829, Val Acc:0.9395
# Epoch 90, Train Loss: 0.0177, Val Loss: 0.1445, Train Acc: 0.9997, Val Acc:0.9594
# Epoch 0, Train Loss: 1.1800, Val Loss: 0.4307, Train Acc: 0.9046, Val Acc:0.8737
# Epoch 10, Train Loss: 0.0631, Val Loss: 0.2497, Train Acc: 0.9897, Val Acc:0.9318
# Epoch 20, Train Loss: 0.0517, Val Loss: 0.2629, Train Acc: 0.9851, Val Acc:0.9293
# Epoch 30, Train Loss: 0.0554, Val Loss: 0.2790, Train Acc: 0.9806, Val Acc:0.9335
# Epoch 40, Train Loss: 0.1054, Val Loss: 0.2233, Train Acc: 0.9860, Val Acc:0.9439
# Epoch 50, Train Loss: 0.0473, Val Loss: 0.2214, Train Acc: 0.9842, Val Acc:0.9388
# Epoch 60, Train Loss: 0.0218, Val Loss: 0.1760, Train Acc: 0.9982, Val Acc:0.9514
# Epoch 70, Train Loss: 0.0265, Val Loss: 0.1518, Train Acc: 0.9979, Val Acc:0.9590
# Epoch 80, Train Loss: 0.0811, Val Loss: 0.2083, Train Acc: 0.9883, Val Acc:0.9454
# Epoch 90, Train Loss: 0.0282, Val Loss: 0.1914, Train Acc: 0.9926, Val Acc:0.9422
# → Moyenne CV accuracy pour lr=0.001, bs=64 : 0.9521
# Testing learning_rate=0.001, batch_size=128 ...
# Epoch 0, Train Loss: 1.5926, Val Loss: 0.5201, Train Acc: 0.8618, Val Acc:0.8485
# Epoch 10, Train Loss: 0.0436, Val Loss: 0.2192, Train Acc: 0.9967, Val Acc:0.9427
# Epoch 20, Train Loss: 0.0298, Val Loss: 0.2124, Train Acc: 0.9984, Val Acc:0.9473
# Epoch 30, Train Loss: 0.0075, Val Loss: 0.1891, Train Acc: 0.9999, Val Acc:0.9517
# Epoch 40, Train Loss: 0.0075, Val Loss: 0.1907, Train Acc: 0.9999, Val Acc:0.9536
# Epoch 50, Train Loss: 0.0107, Val Loss: 0.1843, Train Acc: 0.9998, Val Acc:0.9522
# Epoch 60, Train Loss: 0.0608, Val Loss: 0.2306, Train Acc: 0.9953, Val Acc:0.9463
# Epoch 70, Train Loss: 0.0204, Val Loss: 0.2232, Train Acc: 0.9910, Val Acc:0.9381
# Epoch 80, Train Loss: 0.0086, Val Loss: 0.1534, Train Acc: 0.9999, Val Acc:0.9556
# Epoch 90, Train Loss: 0.0065, Val Loss: 0.1563, Train Acc: 1.0000, Val Acc:0.9575
# Epoch 0, Train Loss: 1.5542, Val Loss: 0.5119, Train Acc: 0.8653, Val Acc:0.8492
# Epoch 10, Train Loss: 0.0426, Val Loss: 0.2280, Train Acc: 0.9970, Val Acc:0.9340
# Epoch 20, Train Loss: 0.0237, Val Loss: 0.2376, Train Acc: 0.9945, Val Acc:0.9345
# Epoch 30, Train Loss: 0.0140, Val Loss: 0.1900, Train Acc: 0.9996, Val Acc:0.9456
# Epoch 40, Train Loss: 0.0115, Val Loss: 0.1775, Train Acc: 1.0000, Val Acc:0.9485
# Epoch 50, Train Loss: 0.0093, Val Loss: 0.1656, Train Acc: 0.9999, Val Acc:0.9522
# Epoch 60, Train Loss: 0.0071, Val Loss: 0.1614, Train Acc: 1.0000, Val Acc:0.9568
# Epoch 70, Train Loss: 0.0048, Val Loss: 0.1647, Train Acc: 1.0000, Val Acc:0.9531
# Epoch 80, Train Loss: 0.0045, Val Loss: 0.1614, Train Acc: 1.0000, Val Acc:0.9573
# Epoch 90, Train Loss: 0.0070, Val Loss: 0.1851, Train Acc: 0.9998, Val Acc:0.9529
# Epoch 0, Train Loss: 1.5893, Val Loss: 0.5140, Train Acc: 0.8646, Val Acc:0.8531
# Epoch 10, Train Loss: 0.0441, Val Loss: 0.2234, Train Acc: 0.9948, Val Acc:0.9376
# Epoch 20, Train Loss: 0.0608, Val Loss: 0.2517, Train Acc: 0.9880, Val Acc:0.9378
# Epoch 30, Train Loss: 0.0349, Val Loss: 0.2169, Train Acc: 0.9978, Val Acc:0.9478
# Epoch 40, Train Loss: 0.0596, Val Loss: 0.2347, Train Acc: 0.9941, Val Acc:0.9429
# Epoch 50, Train Loss: 0.0987, Val Loss: 0.2988, Train Acc: 0.9700, Val Acc:0.9235
# Epoch 60, Train Loss: 0.0104, Val Loss: 0.1581, Train Acc: 1.0000, Val Acc:0.9575
# Epoch 70, Train Loss: 0.0075, Val Loss: 0.1566, Train Acc: 1.0000, Val Acc:0.9582
# Epoch 80, Train Loss: 0.0060, Val Loss: 0.1511, Train Acc: 1.0000, Val Acc:0.9592
# Epoch 90, Train Loss: 0.0041, Val Loss: 0.1520, Train Acc: 1.0000, Val Acc:0.9604
# Epoch 0, Train Loss: 1.6601, Val Loss: 0.5559, Train Acc: 0.8387, Val Acc:0.8288
# Epoch 10, Train Loss: 0.0407, Val Loss: 0.2140, Train Acc: 0.9958, Val Acc:0.9424
# Epoch 20, Train Loss: 0.0167, Val Loss: 0.2022, Train Acc: 0.9998, Val Acc:0.9473
# Epoch 30, Train Loss: 0.0117, Val Loss: 0.1720, Train Acc: 0.9999, Val Acc:0.9505
# Epoch 40, Train Loss: 0.0093, Val Loss: 0.1582, Train Acc: 1.0000, Val Acc:0.9553
# Epoch 50, Train Loss: 0.0077, Val Loss: 0.1548, Train Acc: 1.0000, Val Acc:0.9592
# Epoch 60, Train Loss: 0.0051, Val Loss: 0.1510, Train Acc: 1.0000, Val Acc:0.9609
# Epoch 70, Train Loss: 0.0064, Val Loss: 0.1524, Train Acc: 1.0000, Val Acc:0.9614
# Epoch 80, Train Loss: 0.1091, Val Loss: 0.2883, Train Acc: 0.9775, Val Acc:0.9356
# Epoch 90, Train Loss: 0.0086, Val Loss: 0.1477, Train Acc: 1.0000, Val Acc:0.9565
# Epoch 0, Train Loss: 1.6004, Val Loss: 0.5209, Train Acc: 0.8662, Val Acc:0.8451
# Epoch 10, Train Loss: 0.0418, Val Loss: 0.2270, Train Acc: 0.9965, Val Acc:0.9412
# Epoch 20, Train Loss: 0.0904, Val Loss: 0.3307, Train Acc: 0.9769, Val Acc:0.9254
# Epoch 30, Train Loss: 0.0672, Val Loss: 0.2534, Train Acc: 0.9930, Val Acc:0.9361
# Epoch 40, Train Loss: 0.1208, Val Loss: 0.2529, Train Acc: 0.9854, Val Acc:0.9403
# Epoch 50, Train Loss: 0.0718, Val Loss: 0.3122, Train Acc: 0.9741, Val Acc:0.9274
# Epoch 60, Train Loss: 0.0274, Val Loss: 0.2787, Train Acc: 0.9788, Val Acc:0.9257
# Epoch 70, Train Loss: 0.0091, Val Loss: 0.1447, Train Acc: 0.9999, Val Acc:0.9587
# Epoch 80, Train Loss: 0.0066, Val Loss: 0.1436, Train Acc: 1.0000, Val Acc:0.9641
# Epoch 90, Train Loss: 0.0041, Val Loss: 0.1587, Train Acc: 1.0000, Val Acc:0.9604
# → Moyenne CV accuracy pour lr=0.001, bs=128 : 0.9467
# Testing learning_rate=0.001, batch_size=256 ...
# Epoch 0, Train Loss: 2.3071, Val Loss: 0.8686, Train Acc: 0.7546, Val Acc:0.7419
# Epoch 10, Train Loss: 0.0509, Val Loss: 0.2150, Train Acc: 0.9968, Val Acc:0.9420
# Epoch 20, Train Loss: 0.0185, Val Loss: 0.2142, Train Acc: 0.9989, Val Acc:0.9437
# Epoch 30, Train Loss: 0.0079, Val Loss: 0.2124, Train Acc: 1.0000, Val Acc:0.9471
# Epoch 40, Train Loss: 0.0320, Val Loss: 0.2631, Train Acc: 0.9975, Val Acc:0.9449
# Epoch 50, Train Loss: 0.0050, Val Loss: 0.1976, Train Acc: 1.0000, Val Acc:0.9510
# Epoch 60, Train Loss: 0.0076, Val Loss: 0.2024, Train Acc: 0.9982, Val Acc:0.9510
# Epoch 70, Train Loss: 0.0026, Val Loss: 0.1944, Train Acc: 1.0000, Val Acc:0.9551
# Epoch 80, Train Loss: 0.0048, Val Loss: 0.1785, Train Acc: 1.0000, Val Acc:0.9568
# Epoch 90, Train Loss: 0.0757, Val Loss: 0.3168, Train Acc: 0.9914, Val Acc:0.9359
# Epoch 0, Train Loss: 2.2520, Val Loss: 0.8393, Train Acc: 0.7643, Val Acc:0.7572
# Epoch 10, Train Loss: 0.0466, Val Loss: 0.2293, Train Acc: 0.9965, Val Acc:0.9323
# Epoch 20, Train Loss: 0.0178, Val Loss: 0.2297, Train Acc: 0.9996, Val Acc:0.9383
# Epoch 30, Train Loss: 0.0059, Val Loss: 0.2254, Train Acc: 1.0000, Val Acc:0.9393
# Epoch 40, Train Loss: 0.0394, Val Loss: 0.2885, Train Acc: 0.9940, Val Acc:0.9286
# Epoch 50, Train Loss: 0.0050, Val Loss: 0.1992, Train Acc: 1.0000, Val Acc:0.9444
# Epoch 60, Train Loss: 0.0060, Val Loss: 0.2000, Train Acc: 1.0000, Val Acc:0.9454
# Epoch 70, Train Loss: 0.0023, Val Loss: 0.2176, Train Acc: 1.0000, Val Acc:0.9454
# Epoch 80, Train Loss: 0.0046, Val Loss: 0.1886, Train Acc: 1.0000, Val Acc:0.9459
# Epoch 90, Train Loss: 0.0058, Val Loss: 0.2090, Train Acc: 0.9991, Val Acc:0.9456
# Epoch 0, Train Loss: 2.3108, Val Loss: 0.8705, Train Acc: 0.7497, Val Acc:0.7552
# Epoch 10, Train Loss: 0.0492, Val Loss: 0.2197, Train Acc: 0.9956, Val Acc:0.9403
# Epoch 20, Train Loss: 0.0175, Val Loss: 0.2109, Train Acc: 0.9997, Val Acc:0.9437
# Epoch 30, Train Loss: 0.0077, Val Loss: 0.2086, Train Acc: 1.0000, Val Acc:0.9463
# Epoch 40, Train Loss: 0.0038, Val Loss: 0.2247, Train Acc: 1.0000, Val Acc:0.9466
# Epoch 50, Train Loss: 0.0061, Val Loss: 0.1910, Train Acc: 1.0000, Val Acc:0.9500
# Epoch 60, Train Loss: 0.0025, Val Loss: 0.2164, Train Acc: 1.0000, Val Acc:0.9507
# Epoch 70, Train Loss: 0.0050, Val Loss: 0.1825, Train Acc: 1.0000, Val Acc:0.9536
# Epoch 80, Train Loss: 0.0841, Val Loss: 0.2668, Train Acc: 0.9943, Val Acc:0.9415
# Epoch 90, Train Loss: 0.0029, Val Loss: 0.1813, Train Acc: 1.0000, Val Acc:0.9541
# Epoch 0, Train Loss: 2.3315, Val Loss: 0.9068, Train Acc: 0.7403, Val Acc:0.7295
# Epoch 10, Train Loss: 0.0471, Val Loss: 0.2025, Train Acc: 0.9968, Val Acc:0.9432
# Epoch 20, Train Loss: 0.0214, Val Loss: 0.2108, Train Acc: 0.9995, Val Acc:0.9451
# Epoch 30, Train Loss: 0.0115, Val Loss: 0.2108, Train Acc: 0.9999, Val Acc:0.9480
# Epoch 40, Train Loss: 0.0833, Val Loss: 0.3023, Train Acc: 0.9886, Val Acc:0.9354
# Epoch 50, Train Loss: 0.0042, Val Loss: 0.1878, Train Acc: 1.0000, Val Acc:0.9526
# Epoch 60, Train Loss: 0.0060, Val Loss: 0.1779, Train Acc: 1.0000, Val Acc:0.9534
# Epoch 70, Train Loss: 0.0022, Val Loss: 0.2082, Train Acc: 1.0000, Val Acc:0.9517
# Epoch 80, Train Loss: 0.0042, Val Loss: 0.1767, Train Acc: 1.0000, Val Acc:0.9543
# Epoch 90, Train Loss: 0.0046, Val Loss: 0.1757, Train Acc: 1.0000, Val Acc:0.9534
# Epoch 0, Train Loss: 2.3212, Val Loss: 0.9424, Train Acc: 0.7342, Val Acc:0.7190
# Epoch 10, Train Loss: 0.0459, Val Loss: 0.2168, Train Acc: 0.9966, Val Acc:0.9422
# Epoch 20, Train Loss: 0.0188, Val Loss: 0.2238, Train Acc: 0.9995, Val Acc:0.9405
# Epoch 30, Train Loss: 0.0080, Val Loss: 0.2093, Train Acc: 1.0000, Val Acc:0.9461
# Epoch 40, Train Loss: 0.0036, Val Loss: 0.2146, Train Acc: 1.0000, Val Acc:0.9502
# Epoch 50, Train Loss: 0.0059, Val Loss: 0.1821, Train Acc: 1.0000, Val Acc:0.9563
# Epoch 60, Train Loss: 0.0038, Val Loss: 0.2190, Train Acc: 1.0000, Val Acc:0.9536
# Epoch 70, Train Loss: 0.0041, Val Loss: 0.1715, Train Acc: 1.0000, Val Acc:0.9551
# Epoch 80, Train Loss: 0.0859, Val Loss: 0.3512, Train Acc: 0.9729, Val Acc:0.9216
# Epoch 90, Train Loss: 0.0024, Val Loss: 0.1757, Train Acc: 1.0000, Val Acc:0.9580
# → Moyenne CV accuracy pour lr=0.001, bs=256 : 0.9539
# Testing learning_rate=0.01, batch_size=64 ...
# Epoch 0, Train Loss: 0.8942, Val Loss: 0.5838, Train Acc: 0.8406, Val Acc:0.8291
# Epoch 10, Train Loss: 0.4973, Val Loss: 0.5117, Train Acc: 0.8786, Val Acc:0.8694
# Epoch 20, Train Loss: 0.4368, Val Loss: 0.4491, Train Acc: 0.8995, Val Acc:0.8791
# Epoch 30, Train Loss: 0.4105, Val Loss: 0.4228, Train Acc: 0.9080, Val Acc:0.8823
# Epoch 40, Train Loss: 0.4187, Val Loss: 0.4379, Train Acc: 0.9014, Val Acc:0.8764
# Epoch 50, Train Loss: 0.4054, Val Loss: 0.4186, Train Acc: 0.9055, Val Acc:0.8929
# Epoch 60, Train Loss: 0.3956, Val Loss: 0.4075, Train Acc: 0.9106, Val Acc:0.8891
# Epoch 70, Train Loss: 0.3773, Val Loss: 0.5270, Train Acc: 0.8848, Val Acc:0.8546
# Epoch 80, Train Loss: 0.4176, Val Loss: 0.4575, Train Acc: 0.8889, Val Acc:0.8689
# Epoch 90, Train Loss: 0.3966, Val Loss: 0.4742, Train Acc: 0.8892, Val Acc:0.8650
# Epoch 0, Train Loss: 0.9055, Val Loss: 0.7305, Train Acc: 0.8209, Val Acc:0.7985
# Epoch 10, Train Loss: 0.4648, Val Loss: 0.5294, Train Acc: 0.8835, Val Acc:0.8577
# Epoch 20, Train Loss: 0.3987, Val Loss: 0.4227, Train Acc: 0.9119, Val Acc:0.8830
# Epoch 30, Train Loss: 0.3830, Val Loss: 0.4274, Train Acc: 0.9074, Val Acc:0.8810
# Epoch 40, Train Loss: 0.4106, Val Loss: 0.4445, Train Acc: 0.9091, Val Acc:0.8733
# Epoch 50, Train Loss: 0.3924, Val Loss: 0.5422, Train Acc: 0.8816, Val Acc:0.8495
# Epoch 60, Train Loss: 0.3603, Val Loss: 0.4728, Train Acc: 0.9058, Val Acc:0.8742
# Epoch 70, Train Loss: 0.3769, Val Loss: 0.4476, Train Acc: 0.9099, Val Acc:0.8803
# Epoch 80, Train Loss: 0.3747, Val Loss: 0.4393, Train Acc: 0.9026, Val Acc:0.8708
# Epoch 90, Train Loss: 0.4239, Val Loss: 0.4255, Train Acc: 0.9068, Val Acc:0.8849
# Epoch 0, Train Loss: 0.8589, Val Loss: 0.5337, Train Acc: 0.8559, Val Acc:0.8538
# Epoch 10, Train Loss: 0.4735, Val Loss: 0.6091, Train Acc: 0.8669, Val Acc:0.8392
# Epoch 20, Train Loss: 0.4682, Val Loss: 0.4567, Train Acc: 0.8930, Val Acc:0.8735
# Epoch 30, Train Loss: 0.4132, Val Loss: 0.5171, Train Acc: 0.8887, Val Acc:0.8609
# Epoch 40, Train Loss: 0.4218, Val Loss: 0.3673, Train Acc: 0.9187, Val Acc:0.9004
# Epoch 50, Train Loss: 0.4005, Val Loss: 0.4889, Train Acc: 0.8871, Val Acc:0.8698
# Epoch 60, Train Loss: 0.3870, Val Loss: 0.4450, Train Acc: 0.9040, Val Acc:0.8786
# Epoch 70, Train Loss: 0.4264, Val Loss: 0.4262, Train Acc: 0.9085, Val Acc:0.8876
# Epoch 80, Train Loss: 0.3962, Val Loss: 0.3780, Train Acc: 0.9198, Val Acc:0.8953
# Epoch 90, Train Loss: 0.3904, Val Loss: 0.4113, Train Acc: 0.9134, Val Acc:0.8885
# Epoch 0, Train Loss: 0.9176, Val Loss: 0.6041, Train Acc: 0.8346, Val Acc:0.8130
# Epoch 10, Train Loss: 0.4553, Val Loss: 0.4378, Train Acc: 0.8991, Val Acc:0.8735
# Epoch 20, Train Loss: 0.4161, Val Loss: 0.4874, Train Acc: 0.8890, Val Acc:0.8621
# Epoch 30, Train Loss: 0.4001, Val Loss: 0.4790, Train Acc: 0.8868, Val Acc:0.8652
# Epoch 40, Train Loss: 0.4097, Val Loss: 0.4360, Train Acc: 0.9028, Val Acc:0.8800
# Epoch 50, Train Loss: 0.4149, Val Loss: 0.5265, Train Acc: 0.8702, Val Acc:0.8514
# Epoch 60, Train Loss: 0.4018, Val Loss: 0.4230, Train Acc: 0.9046, Val Acc:0.8893
# Epoch 70, Train Loss: 0.3777, Val Loss: 0.4527, Train Acc: 0.8944, Val Acc:0.8706
# Epoch 80, Train Loss: 0.3779, Val Loss: 0.4539, Train Acc: 0.8947, Val Acc:0.8749
# Epoch 90, Train Loss: 0.3860, Val Loss: 0.3992, Train Acc: 0.9159, Val Acc:0.8893
# Epoch 0, Train Loss: 0.8839, Val Loss: 0.6014, Train Acc: 0.8425, Val Acc:0.8218
# Epoch 10, Train Loss: 0.4528, Val Loss: 0.5170, Train Acc: 0.8871, Val Acc:0.8630
# Epoch 20, Train Loss: 0.4093, Val Loss: 0.4639, Train Acc: 0.8950, Val Acc:0.8732
# Epoch 30, Train Loss: 0.4081, Val Loss: 0.4133, Train Acc: 0.9121, Val Acc:0.8917
# Epoch 40, Train Loss: 0.3942, Val Loss: 0.4586, Train Acc: 0.8893, Val Acc:0.8698
# Epoch 50, Train Loss: 0.4176, Val Loss: 0.4459, Train Acc: 0.9122, Val Acc:0.8885
# Epoch 60, Train Loss: 0.4088, Val Loss: 0.5003, Train Acc: 0.8885, Val Acc:0.8643
# Epoch 70, Train Loss: 0.3757, Val Loss: 0.4194, Train Acc: 0.9080, Val Acc:0.8871
# Epoch 80, Train Loss: 0.3967, Val Loss: 0.3570, Train Acc: 0.9287, Val Acc:0.9007
# Epoch 90, Train Loss: 0.3948, Val Loss: 0.4242, Train Acc: 0.9049, Val Acc:0.8868
# → Moyenne CV accuracy pour lr=0.01, bs=64 : 0.8739
# Testing learning_rate=0.01, batch_size=128 ...
# Epoch 0, Train Loss: 0.7881, Val Loss: 0.4144, Train Acc: 0.9007, Val Acc:0.8755
# Epoch 10, Train Loss: 0.2961, Val Loss: 0.3267, Train Acc: 0.9432, Val Acc:0.9109
# Epoch 20, Train Loss: 0.2611, Val Loss: 0.3099, Train Acc: 0.9510, Val Acc:0.9192
# Epoch 30, Train Loss: 0.2617, Val Loss: 0.3779, Train Acc: 0.9338, Val Acc:0.9039
# Epoch 40, Train Loss: 0.2548, Val Loss: 0.3474, Train Acc: 0.9402, Val Acc:0.9077
# Epoch 50, Train Loss: 0.2403, Val Loss: 0.3798, Train Acc: 0.9313, Val Acc:0.9048
# Epoch 60, Train Loss: 0.2263, Val Loss: 0.3490, Train Acc: 0.9458, Val Acc:0.9097
# Epoch 70, Train Loss: 0.2740, Val Loss: 0.4117, Train Acc: 0.9227, Val Acc:0.8958
# Epoch 80, Train Loss: 0.2493, Val Loss: 0.3493, Train Acc: 0.9394, Val Acc:0.9039
# Epoch 90, Train Loss: 0.2522, Val Loss: 0.3645, Train Acc: 0.9374, Val Acc:0.9056
# Epoch 0, Train Loss: 0.7679, Val Loss: 0.4225, Train Acc: 0.8991, Val Acc:0.8721
# Epoch 10, Train Loss: 0.3162, Val Loss: 0.4604, Train Acc: 0.9133, Val Acc:0.8813
# Epoch 20, Train Loss: 0.2675, Val Loss: 0.3758, Train Acc: 0.9299, Val Acc:0.8951
# Epoch 30, Train Loss: 0.2771, Val Loss: 0.3769, Train Acc: 0.9368, Val Acc:0.9007
# Epoch 40, Train Loss: 0.2716, Val Loss: 0.4284, Train Acc: 0.9282, Val Acc:0.8939
# Epoch 50, Train Loss: 0.2776, Val Loss: 0.3549, Train Acc: 0.9392, Val Acc:0.9024
# Epoch 60, Train Loss: 0.2522, Val Loss: 0.3471, Train Acc: 0.9458, Val Acc:0.9065
# Epoch 70, Train Loss: 0.2728, Val Loss: 0.3246, Train Acc: 0.9529, Val Acc:0.9128
# Epoch 80, Train Loss: 0.2372, Val Loss: 0.4392, Train Acc: 0.9231, Val Acc:0.8876
# Epoch 90, Train Loss: 0.2325, Val Loss: 0.4090, Train Acc: 0.9346, Val Acc:0.8898
# Epoch 0, Train Loss: 0.7997, Val Loss: 0.4895, Train Acc: 0.8840, Val Acc:0.8524
# Epoch 10, Train Loss: 0.3581, Val Loss: 0.4494, Train Acc: 0.9082, Val Acc:0.8859
# Epoch 20, Train Loss: 0.2951, Val Loss: 0.4133, Train Acc: 0.9206, Val Acc:0.8961
# Epoch 30, Train Loss: 0.2743, Val Loss: 0.3335, Train Acc: 0.9323, Val Acc:0.9109
# Epoch 40, Train Loss: 0.2431, Val Loss: 0.4356, Train Acc: 0.9267, Val Acc:0.8927
# Epoch 50, Train Loss: 0.2459, Val Loss: 0.3906, Train Acc: 0.9219, Val Acc:0.8951
# Epoch 60, Train Loss: 0.2234, Val Loss: 0.3284, Train Acc: 0.9477, Val Acc:0.9138
# Epoch 70, Train Loss: 0.2575, Val Loss: 0.3075, Train Acc: 0.9473, Val Acc:0.9138
# Epoch 80, Train Loss: 0.2503, Val Loss: 0.3578, Train Acc: 0.9428, Val Acc:0.9104
# Epoch 90, Train Loss: 0.2196, Val Loss: 0.3185, Train Acc: 0.9476, Val Acc:0.9148
# Epoch 0, Train Loss: 0.8293, Val Loss: 0.4795, Train Acc: 0.8840, Val Acc:0.8645
# Epoch 10, Train Loss: 0.3076, Val Loss: 0.4087, Train Acc: 0.9235, Val Acc:0.8934
# Epoch 20, Train Loss: 0.3079, Val Loss: 0.3632, Train Acc: 0.9309, Val Acc:0.9058
# Epoch 30, Train Loss: 0.2435, Val Loss: 0.3430, Train Acc: 0.9359, Val Acc:0.9012
# Epoch 40, Train Loss: 0.2156, Val Loss: 0.3635, Train Acc: 0.9374, Val Acc:0.9038
# Epoch 50, Train Loss: 0.2364, Val Loss: 0.3172, Train Acc: 0.9459, Val Acc:0.9157
# Epoch 60, Train Loss: 0.2610, Val Loss: 0.4132, Train Acc: 0.9360, Val Acc:0.9019
# Epoch 70, Train Loss: 0.2579, Val Loss: 0.3562, Train Acc: 0.9367, Val Acc:0.9089
# Epoch 80, Train Loss: 0.2198, Val Loss: 0.3323, Train Acc: 0.9431, Val Acc:0.9145
# Epoch 90, Train Loss: 0.2371, Val Loss: 0.3277, Train Acc: 0.9547, Val Acc:0.9179
# Epoch 0, Train Loss: 0.7746, Val Loss: 0.4836, Train Acc: 0.8902, Val Acc:0.8475
# Epoch 10, Train Loss: 0.3007, Val Loss: 0.3861, Train Acc: 0.9340, Val Acc:0.8953
# Epoch 20, Train Loss: 0.2666, Val Loss: 0.4196, Train Acc: 0.9276, Val Acc:0.9017
# Epoch 30, Train Loss: 0.2623, Val Loss: 0.3701, Train Acc: 0.9478, Val Acc:0.9106
# Epoch 40, Train Loss: 0.2457, Val Loss: 0.3943, Train Acc: 0.9378, Val Acc:0.8997
# Epoch 50, Train Loss: 0.2364, Val Loss: 0.4063, Train Acc: 0.9386, Val Acc:0.8961
# Epoch 60, Train Loss: 0.2322, Val Loss: 0.3398, Train Acc: 0.9434, Val Acc:0.9080
# Epoch 70, Train Loss: 0.2310, Val Loss: 0.3437, Train Acc: 0.9466, Val Acc:0.9131
# Epoch 80, Train Loss: 0.2479, Val Loss: 0.3448, Train Acc: 0.9489, Val Acc:0.9140
# Epoch 90, Train Loss: 0.2484, Val Loss: 0.3145, Train Acc: 0.9511, Val Acc:0.9203
# → Moyenne CV accuracy pour lr=0.01, bs=128 : 0.9093
# Testing learning_rate=0.01, batch_size=256 ...
# Epoch 0, Train Loss: 0.8958, Val Loss: 0.3707, Train Acc: 0.9201, Val Acc:0.8895
# Epoch 10, Train Loss: 0.1914, Val Loss: 0.3174, Train Acc: 0.9628, Val Acc:0.9184
# Epoch 20, Train Loss: 0.1557, Val Loss: 0.3398, Train Acc: 0.9599, Val Acc:0.9175
# Epoch 30, Train Loss: 0.1758, Val Loss: 0.4343, Train Acc: 0.9541, Val Acc:0.9080
# Epoch 40, Train Loss: 0.1679, Val Loss: 0.3378, Train Acc: 0.9579, Val Acc:0.9247
# Epoch 50, Train Loss: 0.1256, Val Loss: 0.2907, Train Acc: 0.9706, Val Acc:0.9296
# Epoch 60, Train Loss: 0.1771, Val Loss: 0.3753, Train Acc: 0.9605, Val Acc:0.9264
# Epoch 70, Train Loss: 0.1373, Val Loss: 0.3055, Train Acc: 0.9718, Val Acc:0.9349
# Epoch 80, Train Loss: 0.1267, Val Loss: 0.3326, Train Acc: 0.9700, Val Acc:0.9281
# Epoch 90, Train Loss: 0.1873, Val Loss: 0.3409, Train Acc: 0.9691, Val Acc:0.9233
# Epoch 0, Train Loss: 0.8614, Val Loss: 0.3366, Train Acc: 0.9264, Val Acc:0.8951
# Epoch 10, Train Loss: 0.1790, Val Loss: 0.3214, Train Acc: 0.9675, Val Acc:0.9223
# Epoch 20, Train Loss: 0.1687, Val Loss: 0.3484, Train Acc: 0.9671, Val Acc:0.9194
# Epoch 30, Train Loss: 0.1050, Val Loss: 0.3186, Train Acc: 0.9695, Val Acc:0.9255
# Epoch 40, Train Loss: 0.1565, Val Loss: 0.3186, Train Acc: 0.9713, Val Acc:0.9245
# Epoch 50, Train Loss: 0.1843, Val Loss: 0.3730, Train Acc: 0.9693, Val Acc:0.9189
# Epoch 60, Train Loss: 0.1906, Val Loss: 0.3905, Train Acc: 0.9611, Val Acc:0.9177
# Epoch 70, Train Loss: 0.1164, Val Loss: 0.3099, Train Acc: 0.9770, Val Acc:0.9328
# Epoch 80, Train Loss: 0.1469, Val Loss: 0.3521, Train Acc: 0.9695, Val Acc:0.9230
# Epoch 90, Train Loss: 0.0957, Val Loss: 0.3329, Train Acc: 0.9800, Val Acc:0.9313
# Epoch 0, Train Loss: 0.9039, Val Loss: 0.3166, Train Acc: 0.9282, Val Acc:0.9058
# Epoch 10, Train Loss: 0.2201, Val Loss: 0.3765, Train Acc: 0.9511, Val Acc:0.9162
# Epoch 20, Train Loss: 0.1560, Val Loss: 0.3522, Train Acc: 0.9623, Val Acc:0.9291
# Epoch 30, Train Loss: 0.1688, Val Loss: 0.3752, Train Acc: 0.9633, Val Acc:0.9271
# Epoch 40, Train Loss: 0.1490, Val Loss: 0.3471, Train Acc: 0.9671, Val Acc:0.9242
# Epoch 50, Train Loss: 0.1381, Val Loss: 0.2845, Train Acc: 0.9746, Val Acc:0.9415
# Epoch 60, Train Loss: 0.1689, Val Loss: 0.3445, Train Acc: 0.9667, Val Acc:0.9216
# Epoch 70, Train Loss: 0.1696, Val Loss: 0.4166, Train Acc: 0.9654, Val Acc:0.9191
# Epoch 80, Train Loss: 0.2249, Val Loss: 0.3768, Train Acc: 0.9604, Val Acc:0.9206
# Epoch 90, Train Loss: 0.1221, Val Loss: 0.2952, Train Acc: 0.9729, Val Acc:0.9339
# Epoch 0, Train Loss: 0.9452, Val Loss: 0.3738, Train Acc: 0.9208, Val Acc:0.8900
# Epoch 10, Train Loss: 0.2264, Val Loss: 0.3630, Train Acc: 0.9494, Val Acc:0.9102
# Epoch 20, Train Loss: 0.1524, Val Loss: 0.3212, Train Acc: 0.9613, Val Acc:0.9220
# Epoch 30, Train Loss: 0.1388, Val Loss: 0.3566, Train Acc: 0.9556, Val Acc:0.9179
# Epoch 40, Train Loss: 0.1969, Val Loss: 0.3492, Train Acc: 0.9641, Val Acc:0.9196
# Epoch 50, Train Loss: 0.1542, Val Loss: 0.3020, Train Acc: 0.9735, Val Acc:0.9303
# Epoch 60, Train Loss: 0.1543, Val Loss: 0.3129, Train Acc: 0.9678, Val Acc:0.9291
# Epoch 70, Train Loss: 0.1413, Val Loss: 0.3029, Train Acc: 0.9731, Val Acc:0.9356
# Epoch 80, Train Loss: 0.1697, Val Loss: 0.4188, Train Acc: 0.9639, Val Acc:0.9206
# Epoch 90, Train Loss: 0.1100, Val Loss: 0.3533, Train Acc: 0.9709, Val Acc:0.9303
# Epoch 0, Train Loss: 0.9037, Val Loss: 0.3800, Train Acc: 0.9140, Val Acc:0.8873
# Epoch 10, Train Loss: 0.1911, Val Loss: 0.4027, Train Acc: 0.9519, Val Acc:0.9070
# Epoch 20, Train Loss: 0.2024, Val Loss: 0.4249, Train Acc: 0.9539, Val Acc:0.9085
# Epoch 30, Train Loss: 0.1911, Val Loss: 0.3914, Train Acc: 0.9567, Val Acc:0.9155
# Epoch 40, Train Loss: 0.1748, Val Loss: 0.4122, Train Acc: 0.9613, Val Acc:0.9138
# Epoch 50, Train Loss: 0.1393, Val Loss: 0.3459, Train Acc: 0.9687, Val Acc:0.9213
# Epoch 60, Train Loss: 0.1368, Val Loss: 0.3540, Train Acc: 0.9666, Val Acc:0.9223
# Epoch 70, Train Loss: 0.1517, Val Loss: 0.3587, Train Acc: 0.9617, Val Acc:0.9206
# Epoch 80, Train Loss: 0.1881, Val Loss: 0.3627, Train Acc: 0.9702, Val Acc:0.9247
# Epoch 90, Train Loss: 0.1297, Val Loss: 0.3096, Train Acc: 0.9705, Val Acc:0.9310
# → Moyenne CV accuracy pour lr=0.01, bs=256 : 0.9283
#
# Meilleure combinaison : learning_rate=0.001, batch_size=256 avec CV accuracy=0.9539
# Epoch 0, Train Loss: 1.9905, Val Loss: 0.6256, Train Acc: 0.8220, Val Acc:0.8220
# Epoch 10, Train Loss: 0.0387, Val Loss: 0.0286, Train Acc: 0.9977, Val Acc:0.9977
# Epoch 20, Train Loss: 0.0156, Val Loss: 0.0119, Train Acc: 0.9996, Val Acc:0.9996
# Epoch 30, Train Loss: 0.0069, Val Loss: 0.0060, Train Acc: 1.0000, Val Acc:1.0000
# Epoch 40, Train Loss: 0.0031, Val Loss: 0.0029, Train Acc: 1.0000, Val Acc:1.0000
# Epoch 50, Train Loss: 0.0088, Val Loss: 0.0113, Train Acc: 0.9990, Val Acc:0.9990
# Epoch 60, Train Loss: 0.0030, Val Loss: 0.0028, Train Acc: 1.0000, Val Acc:1.0000
# Epoch 70, Train Loss: 0.0056, Val Loss: 0.0046, Train Acc: 1.0000, Val Acc:1.0000
# Epoch 80, Train Loss: 0.0024, Val Loss: 0.0022, Train Acc: 1.0000, Val Acc:1.0000
# Epoch 90, Train Loss: 0.0048, Val Loss: 0.0039, Train Acc: 1.0000, Val Acc:1.0000
#
# Rapport de classification (Test set) avec la meilleure combinaison :
#               precision    recall  f1-score   support
#
#            ⴰ       0.99      1.00      0.99       156
#            ⴱ       0.98      0.99      0.99       156
#            ⴳ       0.93      0.96      0.94       156
#           ⴳⵯ       0.96      0.98      0.97       156
#            ⴷ       0.99      0.98      0.98       156
#            ⴹ       0.93      0.88      0.90       156
#            ⴻ       0.97      0.96      0.96       156
#            ⴼ       0.98      0.97      0.97       156
#            ⴽ       0.96      0.97      0.96       156
#           ⴽⵯ       0.97      0.96      0.96       156
#            ⵀ       0.94      0.95      0.95       156
#            ⵃ       0.95      0.96      0.95       156
#            ⵄ       0.99      0.96      0.97       156
#            ⵅ       0.92      0.92      0.92       156
#            ⵇ       0.97      0.95      0.96       156
#            ⵉ       0.94      0.94      0.94       156
#            ⵊ       0.97      0.97      0.97       156
#            ⵍ       0.97      0.97      0.97       156
#            ⵎ       0.94      0.99      0.97       156
#            ⵏ       0.99      0.99      0.99       156
#            ⵓ       0.96      0.96      0.96       156
#            ⵔ       0.91      0.98      0.94       156
#            ⵕ       0.94      0.97      0.96       156
#            ⵖ       0.97      0.99      0.98       156
#            ⵙ       0.98      0.90      0.94       156
#            ⵚ       0.96      0.96      0.96       156
#            ⵛ       0.97      0.97      0.97       156
#            ⵜ       0.97      0.96      0.96       156
#            ⵟ       0.92      0.96      0.94       156
#            ⵡ       0.99      0.99      0.99       156
#            ⵢ       0.97      0.97      0.97       156
#            ⵣ       0.86      0.91      0.88       156
#            ⵥ       0.92      0.83      0.87       156
#
#     accuracy                           0.96      5148
#    macro avg       0.96      0.96      0.96      5148
# weighted avg       0.96      0.96      0.96      5148

# %%
# Dossier d'entrée contenant les images
input_folder = 'C:/Users/yyyiyi/Downloads/AMHCD_64/AMHCD_64/AMHCD_64'

# Dossier de sortie
output_folder = 'C:/Users/yyyiyi/Downloads/TP4/images_augmentees'
os.makedirs(output_folder, exist_ok=True)

# Paramètres
rotation_angles = [15, -15]             # En degrés
translations = [(20, 10), (-10, -20)]   # (déplacement_x, déplacement_y)

# Parcourir chaque image du dossier
for filenamed in os.listdir(input_folder):
    inpsoudossier="C:/Users/yyyiyi/Downloads/AMHCD_64/AMHCD_64/AMHCD_64/"+filenamed
    output_folder_dire=output_folder+"/"+filenamed
    os.mkdir(output_folder_dire)
    if filenamed==".DS_Store":
        print("ne fait pas aucun action")
    else :
        for filename in os.listdir(inpsoudossier):
            if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_path = os.path.join(inpsoudossier, filename)
                image = cv2.imread(image_path)
        
                if image is None:
                    print(f"Erreur lors du chargement de {filename}")
                    continue
        
                h, w = image.shape[:2]
                base_name = os.path.splitext(filename)[0]
        
                # 1. Appliquer des rotations
                for angle in rotation_angles:
                    center = (w // 2, h // 2)
                    M_rot = cv2.getRotationMatrix2D(center, angle, 1.0)
                    rotated = cv2.warpAffine(image, M_rot, (w, h))
                    cv2.imwrite(os.path.join(output_folder_dire, f"{base_name}_rot{angle}.jpg"), rotated)
        
                # 2. Appliquer des translations
                for tx, ty in translations:
                    M_trans = np.float32([[1, 0, tx], [0, 1, ty]])
                    translated = cv2.warpAffine(image, M_trans, (w, h))
                    cv2.imwrite(os.path.join(output_folder_dire, f"{base_name}trans{tx}{ty}.jpg"), translated)

print("Augmentation terminée.")
# Out:
# ne fait pas aucun action
# Augmentation terminée.

# %%
import os
import pandas as pd
import numpy as np
import cv2
from pathlib import Path
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# 1) dossier racine
data_dir = 'C:/Users/yyyiyi/Downloads/TP4/images_augmentees'
csv_path = os.path.join(data_dir, 'new-labels-map.csv')

# 2) lire le CSV (rel_path + glyphe UTF-8)
df = pd.read_csv(
    csv_path,
    header=None,
    names=['rel_path', 'glyph'],
    dtype=str,
    encoding='utf-8'
)

# 3) NORMALISATION des chemins : ne garder que label/filename
def make_full_path(rel_p):
    p = Path(rel_p.lstrip('./'))           # supprime un "./" initial
    sub = p.parts[-2:]                     # ne garder que les 2 derniers segments
    return os.path.join(data_dir, *sub)

df['image_path'] = df['rel_path'].apply(make_full_path)

# 4) vérification d’existence
missing = df.loc[~df['image_path'].apply(os.path.exists), 'image_path']
if not missing.empty:
    raise FileNotFoundError("Fichiers introuvables :\n" + "\n".join(missing.tolist()))
print(f"✅ Chargé {len(df)} images, {df['glyph'].nunique()} classes.")

# 5) encoder les glyphes en entiers
le = LabelEncoder()
df['label_enc'] = le.fit_transform(df['glyph'])
num_classes = len(le.classes_)

# 6) fonction de chargement et prétraitement
def load_and_preprocess(path, target_size=(32,32)):
    img = cv2.imread(path, cv2.IMREAD_COLOR)
    if img is None:
        raise IOError(f"Impossible de charger : {path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, target_size)

    return (img.astype(np.float32) / 255.0).flatten()

# 7) construire X et y
X = np.stack([load_and_preprocess(p) for p in df['image_path']])
y = df['label_enc'].values

# 8) split train/val/test
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=42
)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42
)
scaler = StandardScaler()
# on reshape les vecteurs si nécessaire (ici X_train est shape (n_samples, n_features))
X_train = scaler.fit_transform(X_train)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)
print(f"Train={len(X_train)}, Val={len(X_val)}, Test={len(X_test)}")

# 9) one-hot encoding pour l’entraînement
ohe = OneHotEncoder(sparse_output=False)
y_train_1h = ohe.fit_transform(y_train.reshape(-1,1))
y_val_1h   = ohe.transform(y_val.reshape(-1,1))




# 10) entraîner le modèle
layers = [X_train.shape[1], 64, 32, num_classes]
nn = MultiClassNeuralNetwork(layers, model_optimization="Adam", learning_rate=0.001)
train_losses, val_losses, train_acc, val_acc = nn.train(
    X_train, y_train_1h,
    X_val,   y_val_1h,
    epochs=100, batch_size=128
)

# 11) évaluer sur test
y_pred = nn.predict(X_test)
print("\n=== Classification Report (Test) ===")
print(classification_report(y_test, y_pred, target_names=le.classes_))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title('Matrice de confusion (Test)')
plt.xlabel('Prédit')
plt.ylabel('Réel')
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Courbes de perte et d’accuracy
fig , (ax1 , ax2) = plt.subplots(1, 2, figsize =(12, 5))

# Courbe de perte
ax1.plot(train_losses , label='Train Loss')
ax1.plot(val_losses , label='Validation Loss')
ax1.set_title('Courbe de perte')
ax1.set_xlabel(' poque ')
ax1.set_ylabel('Perte')
ax1.legend ()

# Courbe d’accuracy
ax2.plot(train_acc , label='Train Accuracy ')
ax2.plot(val_acc , label='Validation Accuracy ')
ax2.set_title('Courbe de p r c i s i o n ')
ax2.set_xlabel(' poque ')
ax2.set_ylabel(' P r c i s i o n ')
ax2.legend ()

plt.tight_layout ()
fig.savefig('loss_accuracy_plot.png')
plt.show()
# Out:
# ✅ Chargé 102960 images, 33 classes.
# Train=61776, Val=20592, Test=20592
# Epoch 0, Train Loss: 2.1441, Val Loss: 1.4154, Train Acc: 0.5881, Val Acc:0.5867
# Epoch 10, Train Loss: 0.4858, Val Loss: 0.5802, Train Acc: 0.8671, Val Acc:0.8350
# Epoch 20, Train Loss: 0.3834, Val Loss: 0.5073, Train Acc: 0.8954, Val Acc:0.8552
# Epoch 30, Train Loss: 0.3380, Val Loss: 0.4472, Train Acc: 0.9137, Val Acc:0.8706
# Epoch 40, Train Loss: 0.3255, Val Loss: 0.4843, Train Acc: 0.9063, Val Acc:0.8597
# Epoch 50, Train Loss: 0.3180, Val Loss: 0.4433, Train Acc: 0.9214, Val Acc:0.8731
# Epoch 60, Train Loss: 0.3019, Val Loss: 0.4529, Train Acc: 0.9154, Val Acc:0.8709
# Epoch 70, Train Loss: 0.2981, Val Loss: 0.4406, Train Acc: 0.9144, Val Acc:0.8700
# Epoch 80, Train Loss: 0.2839, Val Loss: 0.4457, Train Acc: 0.9192, Val Acc:0.8739
# Epoch 90, Train Loss: 0.2809, Val Loss: 0.4588, Train Acc: 0.9144, Val Acc:0.8688
#
# === Classification Report (Test) ===
#               precision    recall  f1-score   support
#
#            ⴰ       0.98      0.99      0.99       624
#            ⴱ       0.97      0.90      0.93       624
#            ⴳ       0.85      0.81      0.83       624
#           ⴳⵯ       0.87      0.83      0.85       624
#            ⴷ       0.86      0.93      0.89       624
#            ⴹ       0.73      0.94      0.82       624
#            ⴻ       0.87      0.87      0.87       624
#            ⴼ       0.87      0.90      0.89       624
#            ⴽ       0.80      0.80      0.80       624
#           ⴽⵯ       0.89      0.80      0.84       624
#            ⵀ       0.92      0.94      0.93       624
#            ⵃ       0.88      0.83      0.85       624
#            ⵄ       0.94      0.92      0.93       624
#            ⵅ       0.82      0.88      0.85       624
#            ⵇ       0.91      0.84      0.87       624
#            ⵉ       0.85      0.84      0.84       624
#            ⵊ       0.90      0.94      0.92       624
#            ⵍ       0.90      0.87      0.88       624
#            ⵎ       0.91      0.97      0.94       624
#            ⵏ       0.94      0.98      0.96       624
#            ⵓ       0.88      0.88      0.88       624
#            ⵔ       0.82      0.93      0.87       624
#            ⵕ       0.82      0.89      0.85       624
#            ⵖ       0.91      0.91      0.91       624
#            ⵙ       0.90      0.85      0.88       624
#            ⵚ       0.88      0.83      0.86       624
#            ⵛ       0.93      0.82      0.87       624
#            ⵜ       0.91      0.88      0.90       624
#            ⵟ       0.86      0.75      0.80       624
#            ⵡ       0.95      0.97      0.96       624
#            ⵢ       0.84      0.84      0.84       624
#            ⵣ       0.75      0.76      0.75       624
#            ⵥ       0.82      0.79      0.80       624
#
#     accuracy                           0.87     20592
#    macro avg       0.88      0.87      0.87     20592
# weighted avg       0.88      0.87      0.87     20592

# %%
# ----- Définir les hyperparamètres à tester -----
learning_rates = [0.0001,0.001, 0.01]
batch_sizes    = [128,256, 512]
lamda_value    =[0.01,0.1]

n_splits       = 5

# Préparer un tableau pour stocker la performance moyenne (accuracy) pour chaque combinaison
mean_val_accuracy = np.zeros((len(learning_rates), len(batch_sizes),len(lamda_value)))

# ----- Créer une version one-hot de y_temp pour la CV -----
one_hot_encoder = OneHotEncoder(sparse_output=False)
y_temp_one_hot = one_hot_encoder.fit_transform(y_temp.reshape(-1, 1))
assert y_temp_one_hot.shape[0] == X_temp.shape[0] and y_temp_one_hot.shape[1] == num_classes
# Boucle de recherche par cross-validation sur chaque combinaison de hyperparamètres

scaler = StandardScaler()
# on reshape les vecteurs si nécessaire (ici X_train est shape (n_samples, n_features))
X_temp = scaler.fit_transform(X_temp)
X_val   = scaler.transform(X_val)
X_test  = scaler.transform(X_test)
for k ,lm in enumerate(lamda_value):
    for i, lr in enumerate(learning_rates):
        for j, bs in enumerate(batch_sizes):
            print(f"Testing Lamda={lm} learning_rate={lr}, batch_size={bs} ...")
            kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
            fold_accuracies = []
    
            for train_index, val_index in kf.split(X_temp):
                X_train_fold = X_temp[train_index]
                X_val_fold   = X_temp[val_index]
                y_train_fold = y_temp_one_hot[train_index]
                y_val_fold   = y_temp_one_hot[val_index]
    
                # Initialiser un nouveau modèle avec le learning rate courant
                layer_sizes = [X_train_fold.shape[1], 64, 32, num_classes]
                nn = MultiClassNeuralNetwork(layer_sizes, model_optimization="Adam",lamda=lm,learning_rate=lr)
    
                # Entraîner sur ce fold
                _, val_losses, _, val_accs = nn.train(
                    X_train_fold, y_train_fold,
                    X_val_fold,   y_val_fold,
                    epochs=100, batch_size=bs
                )
    
                # Récupérer la dernière accuracy du fold de validation
                fold_accuracies.append(val_accs[-1])
    
            # Calculer la moyenne des accuracies sur les n_splits folds
            mean_val_accuracy[i, j,k] = np.mean(fold_accuracies)
            print(f"→ Moyenne CV accuracy pour lr={lr}, bs={bs} ,lamda={lm} : {mean_val_accuracy[i, j,k]:.4f}")

# Déterminer la combinaison qui a la performance la plus élevée
best_idx = np.unravel_index(np.argmax(mean_val_accuracy), mean_val_accuracy.shape)
best_lr  = learning_rates[best_idx[0]]
best_bs  = batch_sizes[best_idx[1]]
best_lm  = lamda_value[best_idx[2]]
best_acc = mean_val_accuracy[best_idx]
print(f"\nMeilleure combinaison : Lamda= {best_lm}learning_rate={best_lr}, batch_size={best_bs}  avec CV accuracy={best_acc:.4f}")

# ----- Visualisation des résultats sous forme de heatmap -----
plt.figure(figsize=(8, 6))
sns.heatmap(
    mean_val_accuracy,
    annot=True, fmt=".4f",
    xticklabels=batch_sizes,
    yticklabels=learning_rates,
    cmap="YlGnBu"
)
plt.title("Moyenne CV Accuracy\npour chaque combinaison de learning_rate et batch_size")
plt.xlabel("Batch size")
plt.ylabel("Learning rate")
plt.savefig("cv_accuracy_heatmap.png")
plt.show()

# ----- Réentraîner un modèle final sur tout X_temp avec la meilleure combinaison -----
layer_sizes_final = [X_temp.shape[1], 64, 32, num_classes]
nn_final = MultiClassNeuralNetwork(layer_sizes_final,  model_optimization="Adam",lamda=best_lm,learning_rate=best_lr)
# Reconstruire y_temp_one_hot si nécessaire :
# y_temp_one_hot = one_hot_encoder.fit_transform(y_temp.reshape(-1, 1))
nn_final.train(X_temp, y_temp_one_hot, X_temp, y_temp_one_hot, epochs=100, batch_size=best_bs)

# ----- Évaluer le modèle final sur le jeu de test -----
y_test_pred = nn_final.predict(X_test)
print("\nRapport de classification (Test set) avec la meilleure combinaison :")
print(classification_report(y_test, y_pred, target_names=le.classes_))

# Matrice de confusion (Test set)
cm = confusion_matrix(y_test, y_test_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title(f"Matrice de confusion (Test set) - lr={best_lr}, bs={best_bs}")
plt.xlabel("Prédit")
plt.ylabel("Réel")
plt.savefig("confusion_matrix_best.png")
plt.show()
# Out:
# Testing Lamda=0.01 learning_rate=0.0001, batch_size=128 ...
# Epoch 0, Train Loss: 3.1431, Val Loss: 2.6611, Train Acc: 0.2391, Val Acc:0.2298
# Epoch 10, Train Loss: 1.0412, Val Loss: 1.0512, Train Acc: 0.7230, Val Acc:0.7134
# Epoch 20, Train Loss: 0.7555, Val Loss: 0.8050, Train Acc: 0.7978, Val Acc:0.7792
# Epoch 30, Train Loss: 0.6127, Val Loss: 0.6895, Train Acc: 0.8371, Val Acc:0.8135
# Epoch 40, Train Loss: 0.5245, Val Loss: 0.6193, Train Acc: 0.8589, Val Acc:0.8302
# Epoch 50, Train Loss: 0.4620, Val Loss: 0.5780, Train Acc: 0.8764, Val Acc:0.8447
# Epoch 60, Train Loss: 0.4151, Val Loss: 0.5503, Train Acc: 0.8884, Val Acc:0.8524
# Epoch 70, Train Loss: 0.3765, Val Loss: 0.5284, Train Acc: 0.8998, Val Acc:0.8587
# Epoch 80, Train Loss: 0.3449, Val Loss: 0.5120, Train Acc: 0.9078, Val Acc:0.8630
# Epoch 90, Train Loss: 0.3181, Val Loss: 0.5090, Train Acc: 0.9150, Val Acc:0.8642
# Epoch 0, Train Loss: 3.1477, Val Loss: 2.6936, Train Acc: 0.2376, Val Acc:0.2383
# Epoch 10, Train Loss: 1.0524, Val Loss: 1.0767, Train Acc: 0.7219, Val Acc:0.7115
# Epoch 20, Train Loss: 0.7432, Val Loss: 0.8233, Train Acc: 0.8010, Val Acc:0.7780
# Epoch 30, Train Loss: 0.5993, Val Loss: 0.6980, Train Acc: 0.8416, Val Acc:0.8124
# Epoch 40, Train Loss: 0.5073, Val Loss: 0.6259, Train Acc: 0.8648, Val Acc:0.8308
# Epoch 50, Train Loss: 0.4431, Val Loss: 0.5889, Train Acc: 0.8791, Val Acc:0.8395
# Epoch 60, Train Loss: 0.3931, Val Loss: 0.5590, Train Acc: 0.8946, Val Acc:0.8491
# Epoch 70, Train Loss: 0.3546, Val Loss: 0.5370, Train Acc: 0.9042, Val Acc:0.8550
# Epoch 80, Train Loss: 0.3228, Val Loss: 0.5234, Train Acc: 0.9133, Val Acc:0.8590
# Epoch 90, Train Loss: 0.2960, Val Loss: 0.5165, Train Acc: 0.9221, Val Acc:0.8638
# Epoch 0, Train Loss: 3.1209, Val Loss: 2.6377, Train Acc: 0.2384, Val Acc:0.2390
# Epoch 10, Train Loss: 1.0515, Val Loss: 1.0578, Train Acc: 0.7181, Val Acc:0.7132
# Epoch 20, Train Loss: 0.7708, Val Loss: 0.8278, Train Acc: 0.7914, Val Acc:0.7744
# Epoch 30, Train Loss: 0.6265, Val Loss: 0.7022, Train Acc: 0.8328, Val Acc:0.8075
# Epoch 40, Train Loss: 0.5339, Val Loss: 0.6376, Train Acc: 0.8544, Val Acc:0.8245
# Epoch 50, Train Loss: 0.4715, Val Loss: 0.5933, Train Acc: 0.8734, Val Acc:0.8356
# Epoch 60, Train Loss: 0.4224, Val Loss: 0.5609, Train Acc: 0.8884, Val Acc:0.8471
# Epoch 70, Train Loss: 0.3834, Val Loss: 0.5449, Train Acc: 0.8959, Val Acc:0.8532
# Epoch 80, Train Loss: 0.3507, Val Loss: 0.5258, Train Acc: 0.9060, Val Acc:0.8592
# Epoch 90, Train Loss: 0.3219, Val Loss: 0.5155, Train Acc: 0.9131, Val Acc:0.8623
# Epoch 0, Train Loss: 3.1024, Val Loss: 2.5758, Train Acc: 0.2665, Val Acc:0.2652
# Epoch 10, Train Loss: 1.0328, Val Loss: 1.0226, Train Acc: 0.7244, Val Acc:0.7117
# Epoch 20, Train Loss: 0.7608, Val Loss: 0.7783, Train Acc: 0.7989, Val Acc:0.7859
# Epoch 30, Train Loss: 0.6202, Val Loss: 0.6604, Train Acc: 0.8361, Val Acc:0.8168
# Epoch 40, Train Loss: 0.5301, Val Loss: 0.5886, Train Acc: 0.8603, Val Acc:0.8370
# Epoch 50, Train Loss: 0.4650, Val Loss: 0.5495, Train Acc: 0.8748, Val Acc:0.8439
# Epoch 60, Train Loss: 0.4149, Val Loss: 0.5177, Train Acc: 0.8896, Val Acc:0.8570
# Epoch 70, Train Loss: 0.3745, Val Loss: 0.4968, Train Acc: 0.9014, Val Acc:0.8617
# Epoch 80, Train Loss: 0.3434, Val Loss: 0.4876, Train Acc: 0.9084, Val Acc:0.8625
# Epoch 90, Train Loss: 0.3138, Val Loss: 0.4766, Train Acc: 0.9168, Val Acc:0.8700
# Epoch 0, Train Loss: 3.1249, Val Loss: 2.6373, Train Acc: 0.2480, Val Acc:0.2446
# Epoch 10, Train Loss: 1.0653, Val Loss: 1.0656, Train Acc: 0.7111, Val Acc:0.7013
# Epoch 20, Train Loss: 0.7705, Val Loss: 0.8059, Train Acc: 0.7913, Val Acc:0.7730
# Epoch 30, Train Loss: 0.6145, Val Loss: 0.6723, Train Acc: 0.8349, Val Acc:0.8133
# Epoch 40, Train Loss: 0.5172, Val Loss: 0.6028, Train Acc: 0.8621, Val Acc:0.8334
# Epoch 50, Train Loss: 0.4508, Val Loss: 0.5524, Train Acc: 0.8796, Val Acc:0.8461
# Epoch 60, Train Loss: 0.4021, Val Loss: 0.5263, Train Acc: 0.8926, Val Acc:0.8511
# Epoch 70, Train Loss: 0.3624, Val Loss: 0.5014, Train Acc: 0.9055, Val Acc:0.8614
# Epoch 80, Train Loss: 0.3302, Val Loss: 0.4873, Train Acc: 0.9126, Val Acc:0.8626
# Epoch 90, Train Loss: 0.3040, Val Loss: 0.4876, Train Acc: 0.9177, Val Acc:0.8654
# → Moyenne CV accuracy pour lr=0.0001, bs=128 ,lamda=0.01 : 0.8677
# Testing Lamda=0.01 learning_rate=0.0001, batch_size=256 ...
# Epoch 0, Train Loss: 3.3488, Val Loss: 2.9823, Train Acc: 0.1650, Val Acc:0.1593
# Epoch 10, Train Loss: 1.2399, Val Loss: 1.2314, Train Acc: 0.6677, Val Acc:0.6595
# Epoch 20, Train Loss: 0.8951, Val Loss: 0.9261, Train Acc: 0.7618, Val Acc:0.7501
# Epoch 30, Train Loss: 0.7342, Val Loss: 0.7923, Train Acc: 0.8007, Val Acc:0.7832
# Epoch 40, Train Loss: 0.6307, Val Loss: 0.7018, Train Acc: 0.8316, Val Acc:0.8091
# Epoch 50, Train Loss: 0.5569, Val Loss: 0.6433, Train Acc: 0.8497, Val Acc:0.8231
# Epoch 60, Train Loss: 0.4994, Val Loss: 0.5977, Train Acc: 0.8670, Val Acc:0.8382
# Epoch 70, Train Loss: 0.4542, Val Loss: 0.5691, Train Acc: 0.8756, Val Acc:0.8428
# Epoch 80, Train Loss: 0.4172, Val Loss: 0.5418, Train Acc: 0.8877, Val Acc:0.8531
# Epoch 90, Train Loss: 0.3857, Val Loss: 0.5269, Train Acc: 0.8958, Val Acc:0.8594
# Epoch 0, Train Loss: 3.3461, Val Loss: 2.9924, Train Acc: 0.1535, Val Acc:0.1545
# Epoch 10, Train Loss: 1.2959, Val Loss: 1.3027, Train Acc: 0.6550, Val Acc:0.6443
# Epoch 20, Train Loss: 0.9078, Val Loss: 0.9657, Train Acc: 0.7561, Val Acc:0.7423
# Epoch 30, Train Loss: 0.7411, Val Loss: 0.8188, Train Acc: 0.8025, Val Acc:0.7800
# Epoch 40, Train Loss: 0.6334, Val Loss: 0.7305, Train Acc: 0.8306, Val Acc:0.8047
# Epoch 50, Train Loss: 0.5560, Val Loss: 0.6691, Train Acc: 0.8500, Val Acc:0.8198
# Epoch 60, Train Loss: 0.4966, Val Loss: 0.6263, Train Acc: 0.8691, Val Acc:0.8330
# Epoch 70, Train Loss: 0.4497, Val Loss: 0.5915, Train Acc: 0.8785, Val Acc:0.8402
# Epoch 80, Train Loss: 0.4123, Val Loss: 0.5686, Train Acc: 0.8889, Val Acc:0.8460
# Epoch 90, Train Loss: 0.3813, Val Loss: 0.5484, Train Acc: 0.8993, Val Acc:0.8516
# Epoch 0, Train Loss: 3.3425, Val Loss: 2.9564, Train Acc: 0.1692, Val Acc:0.1687
# Epoch 10, Train Loss: 1.2323, Val Loss: 1.2176, Train Acc: 0.6712, Val Acc:0.6675
# Epoch 20, Train Loss: 0.8893, Val Loss: 0.9228, Train Acc: 0.7627, Val Acc:0.7513
# Epoch 30, Train Loss: 0.7325, Val Loss: 0.7914, Train Acc: 0.8049, Val Acc:0.7832
# Epoch 40, Train Loss: 0.6352, Val Loss: 0.7152, Train Acc: 0.8301, Val Acc:0.8055
# Epoch 50, Train Loss: 0.5650, Val Loss: 0.6618, Train Acc: 0.8495, Val Acc:0.8190
# Epoch 60, Train Loss: 0.5090, Val Loss: 0.6221, Train Acc: 0.8637, Val Acc:0.8321
# Epoch 70, Train Loss: 0.4648, Val Loss: 0.5881, Train Acc: 0.8774, Val Acc:0.8402
# Epoch 80, Train Loss: 0.4275, Val Loss: 0.5709, Train Acc: 0.8858, Val Acc:0.8464
# Epoch 90, Train Loss: 0.3960, Val Loss: 0.5449, Train Acc: 0.8952, Val Acc:0.8563
# Epoch 0, Train Loss: 3.3369, Val Loss: 2.9385, Train Acc: 0.1750, Val Acc:0.1756
# Epoch 10, Train Loss: 1.2463, Val Loss: 1.2234, Train Acc: 0.6646, Val Acc:0.6536
# Epoch 20, Train Loss: 0.9036, Val Loss: 0.9109, Train Acc: 0.7590, Val Acc:0.7445
# Epoch 30, Train Loss: 0.7350, Val Loss: 0.7596, Train Acc: 0.8053, Val Acc:0.7925
# Epoch 40, Train Loss: 0.6274, Val Loss: 0.6718, Train Acc: 0.8342, Val Acc:0.8145
# Epoch 50, Train Loss: 0.5528, Val Loss: 0.6121, Train Acc: 0.8545, Val Acc:0.8320
# Epoch 60, Train Loss: 0.4969, Val Loss: 0.5726, Train Acc: 0.8676, Val Acc:0.8420
# Epoch 70, Train Loss: 0.4520, Val Loss: 0.5467, Train Acc: 0.8803, Val Acc:0.8498
# Epoch 80, Train Loss: 0.4167, Val Loss: 0.5282, Train Acc: 0.8877, Val Acc:0.8547
# Epoch 90, Train Loss: 0.3858, Val Loss: 0.5090, Train Acc: 0.8980, Val Acc:0.8615
# Epoch 0, Train Loss: 3.3400, Val Loss: 2.9795, Train Acc: 0.1632, Val Acc:0.1627
# Epoch 10, Train Loss: 1.2294, Val Loss: 1.2156, Train Acc: 0.6685, Val Acc:0.6623
# Epoch 20, Train Loss: 0.8942, Val Loss: 0.9158, Train Acc: 0.7595, Val Acc:0.7462
# Epoch 30, Train Loss: 0.7346, Val Loss: 0.7800, Train Acc: 0.7999, Val Acc:0.7848
# Epoch 40, Train Loss: 0.6315, Val Loss: 0.6942, Train Acc: 0.8313, Val Acc:0.8097
# Epoch 50, Train Loss: 0.5595, Val Loss: 0.6378, Train Acc: 0.8487, Val Acc:0.8224
# Epoch 60, Train Loss: 0.5052, Val Loss: 0.6011, Train Acc: 0.8638, Val Acc:0.8323
# Epoch 70, Train Loss: 0.4634, Val Loss: 0.5670, Train Acc: 0.8754, Val Acc:0.8438
# Epoch 80, Train Loss: 0.4275, Val Loss: 0.5449, Train Acc: 0.8851, Val Acc:0.8499
# Epoch 90, Train Loss: 0.3974, Val Loss: 0.5312, Train Acc: 0.8922, Val Acc:0.8549
# → Moyenne CV accuracy pour lr=0.0001, bs=256 ,lamda=0.01 : 0.8589
# Testing Lamda=0.01 learning_rate=0.0001, batch_size=512 ...
# Epoch 0, Train Loss: 3.4885, Val Loss: 3.3361, Train Acc: 0.0937, Val Acc:0.0944
# Epoch 10, Train Loss: 1.5234, Val Loss: 1.4994, Train Acc: 0.5855, Val Acc:0.5781
# Epoch 20, Train Loss: 1.0709, Val Loss: 1.0831, Train Acc: 0.7132, Val Acc:0.7034
# Epoch 30, Train Loss: 0.8776, Val Loss: 0.9101, Train Acc: 0.7667, Val Acc:0.7523
# Epoch 40, Train Loss: 0.7612, Val Loss: 0.8127, Train Acc: 0.7944, Val Acc:0.7770
# Epoch 50, Train Loss: 0.6803, Val Loss: 0.7429, Train Acc: 0.8181, Val Acc:0.7962
# Epoch 60, Train Loss: 0.6178, Val Loss: 0.6932, Train Acc: 0.8366, Val Acc:0.8123
# Epoch 70, Train Loss: 0.5677, Val Loss: 0.6566, Train Acc: 0.8481, Val Acc:0.8219
# Epoch 80, Train Loss: 0.5268, Val Loss: 0.6234, Train Acc: 0.8582, Val Acc:0.8311
# Epoch 90, Train Loss: 0.4925, Val Loss: 0.5968, Train Acc: 0.8682, Val Acc:0.8383
# Epoch 0, Train Loss: 3.4877, Val Loss: 3.3296, Train Acc: 0.0933, Val Acc:0.0931
# Epoch 10, Train Loss: 1.5814, Val Loss: 1.5636, Train Acc: 0.5698, Val Acc:0.5638
# Epoch 20, Train Loss: 1.0976, Val Loss: 1.1285, Train Acc: 0.7049, Val Acc:0.6928
# Epoch 30, Train Loss: 0.8965, Val Loss: 0.9496, Train Acc: 0.7587, Val Acc:0.7418
# Epoch 40, Train Loss: 0.7775, Val Loss: 0.8481, Train Acc: 0.7933, Val Acc:0.7735
# Epoch 50, Train Loss: 0.6926, Val Loss: 0.7789, Train Acc: 0.8137, Val Acc:0.7923
# Epoch 60, Train Loss: 0.6258, Val Loss: 0.7257, Train Acc: 0.8321, Val Acc:0.8072
# Epoch 70, Train Loss: 0.5715, Val Loss: 0.6788, Train Acc: 0.8481, Val Acc:0.8189
# Epoch 80, Train Loss: 0.5271, Val Loss: 0.6463, Train Acc: 0.8571, Val Acc:0.8249
# Epoch 90, Train Loss: 0.4894, Val Loss: 0.6167, Train Acc: 0.8689, Val Acc:0.8332
# Epoch 0, Train Loss: 3.4902, Val Loss: 3.3392, Train Acc: 0.0848, Val Acc:0.0856
# Epoch 10, Train Loss: 1.4941, Val Loss: 1.4523, Train Acc: 0.6045, Val Acc:0.6031
# Epoch 20, Train Loss: 1.0616, Val Loss: 1.0767, Train Acc: 0.7129, Val Acc:0.7072
# Epoch 30, Train Loss: 0.8761, Val Loss: 0.9135, Train Acc: 0.7641, Val Acc:0.7537
# Epoch 40, Train Loss: 0.7573, Val Loss: 0.8127, Train Acc: 0.7968, Val Acc:0.7808
# Epoch 50, Train Loss: 0.6727, Val Loss: 0.7378, Train Acc: 0.8210, Val Acc:0.7994
# Epoch 60, Train Loss: 0.6083, Val Loss: 0.6870, Train Acc: 0.8387, Val Acc:0.8129
# Epoch 70, Train Loss: 0.5578, Val Loss: 0.6469, Train Acc: 0.8509, Val Acc:0.8228
# Epoch 80, Train Loss: 0.5157, Val Loss: 0.6140, Train Acc: 0.8633, Val Acc:0.8331
# Epoch 90, Train Loss: 0.4794, Val Loss: 0.5865, Train Acc: 0.8728, Val Acc:0.8424
# Epoch 0, Train Loss: 3.4897, Val Loss: 3.3330, Train Acc: 0.0913, Val Acc:0.0914
# Epoch 10, Train Loss: 1.5472, Val Loss: 1.5050, Train Acc: 0.5856, Val Acc:0.5777
# Epoch 20, Train Loss: 1.1080, Val Loss: 1.0998, Train Acc: 0.7038, Val Acc:0.6914
# Epoch 30, Train Loss: 0.9121, Val Loss: 0.9244, Train Acc: 0.7571, Val Acc:0.7430
# Epoch 40, Train Loss: 0.7948, Val Loss: 0.8211, Train Acc: 0.7898, Val Acc:0.7748
# Epoch 50, Train Loss: 0.7087, Val Loss: 0.7475, Train Acc: 0.8109, Val Acc:0.7937
# Epoch 60, Train Loss: 0.6423, Val Loss: 0.6957, Train Acc: 0.8275, Val Acc:0.8069
# Epoch 70, Train Loss: 0.5892, Val Loss: 0.6504, Train Acc: 0.8420, Val Acc:0.8219
# Epoch 80, Train Loss: 0.5452, Val Loss: 0.6169, Train Acc: 0.8552, Val Acc:0.8294
# Epoch 90, Train Loss: 0.5073, Val Loss: 0.5904, Train Acc: 0.8647, Val Acc:0.8368
# Epoch 0, Train Loss: 3.4865, Val Loss: 3.3306, Train Acc: 0.0917, Val Acc:0.0883
# Epoch 10, Train Loss: 1.5185, Val Loss: 1.4847, Train Acc: 0.5917, Val Acc:0.5806
# Epoch 20, Train Loss: 1.0785, Val Loss: 1.0791, Train Acc: 0.7110, Val Acc:0.7033
# Epoch 30, Train Loss: 0.8874, Val Loss: 0.9136, Train Acc: 0.7639, Val Acc:0.7497
# Epoch 40, Train Loss: 0.7700, Val Loss: 0.8117, Train Acc: 0.7949, Val Acc:0.7788
# Epoch 50, Train Loss: 0.6855, Val Loss: 0.7386, Train Acc: 0.8175, Val Acc:0.7978
# Epoch 60, Train Loss: 0.6212, Val Loss: 0.6848, Train Acc: 0.8353, Val Acc:0.8125
# Epoch 70, Train Loss: 0.5702, Val Loss: 0.6439, Train Acc: 0.8492, Val Acc:0.8240
# Epoch 80, Train Loss: 0.5278, Val Loss: 0.6118, Train Acc: 0.8602, Val Acc:0.8317
# Epoch 90, Train Loss: 0.4922, Val Loss: 0.5884, Train Acc: 0.8682, Val Acc:0.8364
# → Moyenne CV accuracy pour lr=0.0001, bs=512 ,lamda=0.01 : 0.8416
# Testing Lamda=0.01 learning_rate=0.001, batch_size=128 ...
# Epoch 0, Train Loss: 1.9786, Val Loss: 1.2417, Train Acc: 0.6485, Val Acc:0.6433
# Epoch 10, Train Loss: 0.4019, Val Loss: 0.5119, Train Acc: 0.8886, Val Acc:0.8529
# Epoch 20, Train Loss: 0.2912, Val Loss: 0.4753, Train Acc: 0.9254, Val Acc:0.8722
# Epoch 30, Train Loss: 0.2363, Val Loss: 0.4932, Train Acc: 0.9351, Val Acc:0.8708
# Epoch 40, Train Loss: 0.2056, Val Loss: 0.5395, Train Acc: 0.9325, Val Acc:0.8679
# Epoch 50, Train Loss: 0.1845, Val Loss: 0.5139, Train Acc: 0.9525, Val Acc:0.8835
# Epoch 60, Train Loss: 0.1753, Val Loss: 0.5345, Train Acc: 0.9479, Val Acc:0.8773
# Epoch 70, Train Loss: 0.1707, Val Loss: 0.6023, Train Acc: 0.9386, Val Acc:0.8668
# Epoch 80, Train Loss: 0.1540, Val Loss: 0.6465, Train Acc: 0.9280, Val Acc:0.8605
# Epoch 90, Train Loss: 0.1598, Val Loss: 0.5466, Train Acc: 0.9581, Val Acc:0.8844
# Epoch 0, Train Loss: 2.0956, Val Loss: 1.3362, Train Acc: 0.6397, Val Acc:0.6261
# Epoch 10, Train Loss: 0.4247, Val Loss: 0.5691, Train Acc: 0.8828, Val Acc:0.8343
# Epoch 20, Train Loss: 0.3049, Val Loss: 0.5221, Train Acc: 0.9144, Val Acc:0.8604
# Epoch 30, Train Loss: 0.2453, Val Loss: 0.5286, Train Acc: 0.9267, Val Acc:0.8622
# Epoch 40, Train Loss: 0.2163, Val Loss: 0.5316, Train Acc: 0.9404, Val Acc:0.8656
# Epoch 50, Train Loss: 0.1936, Val Loss: 0.5439, Train Acc: 0.9454, Val Acc:0.8705
# Epoch 60, Train Loss: 0.1838, Val Loss: 0.5648, Train Acc: 0.9473, Val Acc:0.8716
# Epoch 70, Train Loss: 0.1703, Val Loss: 0.5394, Train Acc: 0.9606, Val Acc:0.8788
# Epoch 80, Train Loss: 0.1653, Val Loss: 0.6080, Train Acc: 0.9449, Val Acc:0.8641
# Epoch 90, Train Loss: 0.1614, Val Loss: 0.5766, Train Acc: 0.9537, Val Acc:0.8705
# Epoch 0, Train Loss: 2.0637, Val Loss: 1.3074, Train Acc: 0.6311, Val Acc:0.6244
# Epoch 10, Train Loss: 0.4189, Val Loss: 0.5536, Train Acc: 0.8792, Val Acc:0.8412
# Epoch 20, Train Loss: 0.2991, Val Loss: 0.5354, Train Acc: 0.9014, Val Acc:0.8527
# Epoch 30, Train Loss: 0.2485, Val Loss: 0.5384, Train Acc: 0.9176, Val Acc:0.8609
# Epoch 40, Train Loss: 0.2131, Val Loss: 0.6027, Train Acc: 0.9107, Val Acc:0.8470
# Epoch 50, Train Loss: 0.2008, Val Loss: 0.5249, Train Acc: 0.9425, Val Acc:0.8726
# Epoch 60, Train Loss: 0.1829, Val Loss: 0.5618, Train Acc: 0.9419, Val Acc:0.8670
# Epoch 70, Train Loss: 0.1764, Val Loss: 0.5716, Train Acc: 0.9463, Val Acc:0.8733
# Epoch 80, Train Loss: 0.1697, Val Loss: 0.5490, Train Acc: 0.9559, Val Acc:0.8780
# Epoch 90, Train Loss: 0.1576, Val Loss: 0.5955, Train Acc: 0.9473, Val Acc:0.8711
# Epoch 0, Train Loss: 1.9301, Val Loss: 1.1646, Train Acc: 0.6679, Val Acc:0.6614
# Epoch 10, Train Loss: 0.3934, Val Loss: 0.5356, Train Acc: 0.8775, Val Acc:0.8470
# Epoch 20, Train Loss: 0.2834, Val Loss: 0.4860, Train Acc: 0.9136, Val Acc:0.8654
# Epoch 30, Train Loss: 0.2379, Val Loss: 0.4788, Train Acc: 0.9316, Val Acc:0.8766
# Epoch 40, Train Loss: 0.2099, Val Loss: 0.4968, Train Acc: 0.9344, Val Acc:0.8760
# Epoch 50, Train Loss: 0.1864, Val Loss: 0.5355, Train Acc: 0.9362, Val Acc:0.8726
# Epoch 60, Train Loss: 0.1737, Val Loss: 0.5450, Train Acc: 0.9386, Val Acc:0.8695
# Epoch 70, Train Loss: 0.1701, Val Loss: 0.5531, Train Acc: 0.9430, Val Acc:0.8731
# Epoch 80, Train Loss: 0.1559, Val Loss: 0.5365, Train Acc: 0.9526, Val Acc:0.8817
# Epoch 90, Train Loss: 0.1440, Val Loss: 0.5642, Train Acc: 0.9499, Val Acc:0.8773
# Epoch 0, Train Loss: 2.0248, Val Loss: 1.2867, Train Acc: 0.6324, Val Acc:0.6226
# Epoch 10, Train Loss: 0.4152, Val Loss: 0.5187, Train Acc: 0.8911, Val Acc:0.8528
# Epoch 20, Train Loss: 0.3009, Val Loss: 0.4934, Train Acc: 0.9124, Val Acc:0.8615
# Epoch 30, Train Loss: 0.2526, Val Loss: 0.4712, Train Acc: 0.9351, Val Acc:0.8740
# Epoch 40, Train Loss: 0.2121, Val Loss: 0.4967, Train Acc: 0.9432, Val Acc:0.8722
# Epoch 50, Train Loss: 0.1921, Val Loss: 0.5905, Train Acc: 0.9257, Val Acc:0.8578
# Epoch 60, Train Loss: 0.1814, Val Loss: 0.5686, Train Acc: 0.9399, Val Acc:0.8680
# Epoch 70, Train Loss: 0.1771, Val Loss: 0.5021, Train Acc: 0.9614, Val Acc:0.8842
# Epoch 80, Train Loss: 0.1660, Val Loss: 0.5736, Train Acc: 0.9491, Val Acc:0.8704
# Epoch 90, Train Loss: 0.1612, Val Loss: 0.5886, Train Acc: 0.9474, Val Acc:0.8678
# → Moyenne CV accuracy pour lr=0.001, bs=128 ,lamda=0.01 : 0.8689
# Testing Lamda=0.01 learning_rate=0.001, batch_size=256 ...
# Epoch 0, Train Loss: 2.2530, Val Loss: 1.4436, Train Acc: 0.5869, Val Acc:0.5832
# Epoch 10, Train Loss: 0.4345, Val Loss: 0.5592, Train Acc: 0.8721, Val Acc:0.8367
# Epoch 20, Train Loss: 0.2968, Val Loss: 0.4899, Train Acc: 0.9125, Val Acc:0.8611
# Epoch 30, Train Loss: 0.2308, Val Loss: 0.5022, Train Acc: 0.9245, Val Acc:0.8639
# Epoch 40, Train Loss: 0.1847, Val Loss: 0.4794, Train Acc: 0.9511, Val Acc:0.8826
# Epoch 50, Train Loss: 0.1598, Val Loss: 0.5337, Train Acc: 0.9466, Val Acc:0.8716
# Epoch 60, Train Loss: 0.1459, Val Loss: 0.5509, Train Acc: 0.9532, Val Acc:0.8775
# Epoch 70, Train Loss: 0.1222, Val Loss: 0.5603, Train Acc: 0.9651, Val Acc:0.8779
# Epoch 80, Train Loss: 0.1222, Val Loss: 0.5766, Train Acc: 0.9699, Val Acc:0.8817
# Epoch 90, Train Loss: 0.1130, Val Loss: 0.6463, Train Acc: 0.9567, Val Acc:0.8713
# Epoch 0, Train Loss: 2.3161, Val Loss: 1.5382, Train Acc: 0.5737, Val Acc:0.5585
# Epoch 10, Train Loss: 0.4398, Val Loss: 0.5805, Train Acc: 0.8799, Val Acc:0.8368
# Epoch 20, Train Loss: 0.3020, Val Loss: 0.5364, Train Acc: 0.9054, Val Acc:0.8502
# Epoch 30, Train Loss: 0.2321, Val Loss: 0.5277, Train Acc: 0.9276, Val Acc:0.8612
# Epoch 40, Train Loss: 0.1956, Val Loss: 0.5218, Train Acc: 0.9510, Val Acc:0.8689
# Epoch 50, Train Loss: 0.1650, Val Loss: 0.6054, Train Acc: 0.9405, Val Acc:0.8592
# Epoch 60, Train Loss: 0.1498, Val Loss: 0.6182, Train Acc: 0.9542, Val Acc:0.8679
# Epoch 70, Train Loss: 0.1331, Val Loss: 0.6685, Train Acc: 0.9557, Val Acc:0.8630
# Epoch 80, Train Loss: 0.1182, Val Loss: 0.6593, Train Acc: 0.9628, Val Acc:0.8664
# Epoch 90, Train Loss: 0.1176, Val Loss: 0.7013, Train Acc: 0.9636, Val Acc:0.8685
# Epoch 0, Train Loss: 2.2577, Val Loss: 1.3953, Train Acc: 0.6042, Val Acc:0.6046
# Epoch 10, Train Loss: 0.4480, Val Loss: 0.5630, Train Acc: 0.8758, Val Acc:0.8425
# Epoch 20, Train Loss: 0.3026, Val Loss: 0.4753, Train Acc: 0.9234, Val Acc:0.8728
# Epoch 30, Train Loss: 0.2344, Val Loss: 0.4871, Train Acc: 0.9347, Val Acc:0.8732
# Epoch 40, Train Loss: 0.1966, Val Loss: 0.4972, Train Acc: 0.9522, Val Acc:0.8801
# Epoch 50, Train Loss: 0.1687, Val Loss: 0.5569, Train Acc: 0.9496, Val Acc:0.8737
# Epoch 60, Train Loss: 0.1491, Val Loss: 0.5964, Train Acc: 0.9514, Val Acc:0.8697
# Epoch 70, Train Loss: 0.1266, Val Loss: 0.5941, Train Acc: 0.9627, Val Acc:0.8775
# Epoch 80, Train Loss: 0.1212, Val Loss: 0.6122, Train Acc: 0.9638, Val Acc:0.8752
# Epoch 90, Train Loss: 0.1132, Val Loss: 0.6540, Train Acc: 0.9647, Val Acc:0.8740
# Epoch 0, Train Loss: 2.2247, Val Loss: 1.4169, Train Acc: 0.6050, Val Acc:0.5941
# Epoch 10, Train Loss: 0.4526, Val Loss: 0.5389, Train Acc: 0.8742, Val Acc:0.8418
# Epoch 20, Train Loss: 0.3082, Val Loss: 0.4877, Train Acc: 0.9095, Val Acc:0.8624
# Epoch 30, Train Loss: 0.2427, Val Loss: 0.4931, Train Acc: 0.9265, Val Acc:0.8674
# Epoch 40, Train Loss: 0.1964, Val Loss: 0.5030, Train Acc: 0.9407, Val Acc:0.8719
# Epoch 50, Train Loss: 0.1720, Val Loss: 0.5177, Train Acc: 0.9524, Val Acc:0.8759
# Epoch 60, Train Loss: 0.1486, Val Loss: 0.5392, Train Acc: 0.9564, Val Acc:0.8800
# Epoch 70, Train Loss: 0.1259, Val Loss: 0.5725, Train Acc: 0.9601, Val Acc:0.8740
# Epoch 80, Train Loss: 0.1202, Val Loss: 0.6447, Train Acc: 0.9493, Val Acc:0.8699
# Epoch 90, Train Loss: 0.1151, Val Loss: 0.6293, Train Acc: 0.9623, Val Acc:0.8768
# Epoch 0, Train Loss: 2.2712, Val Loss: 1.4839, Train Acc: 0.5644, Val Acc:0.5596
# Epoch 10, Train Loss: 0.4439, Val Loss: 0.5522, Train Acc: 0.8774, Val Acc:0.8458
# Epoch 20, Train Loss: 0.3063, Val Loss: 0.4883, Train Acc: 0.9138, Val Acc:0.8646
# Epoch 30, Train Loss: 0.2367, Val Loss: 0.5083, Train Acc: 0.9221, Val Acc:0.8636
# Epoch 40, Train Loss: 0.1962, Val Loss: 0.5068, Train Acc: 0.9444, Val Acc:0.8713
# Epoch 50, Train Loss: 0.1648, Val Loss: 0.5489, Train Acc: 0.9471, Val Acc:0.8711
# Epoch 60, Train Loss: 0.1456, Val Loss: 0.5558, Train Acc: 0.9605, Val Acc:0.8733
# Epoch 70, Train Loss: 0.1261, Val Loss: 0.6093, Train Acc: 0.9571, Val Acc:0.8688
# Epoch 80, Train Loss: 0.1246, Val Loss: 0.6445, Train Acc: 0.9586, Val Acc:0.8679
# Epoch 90, Train Loss: 0.1173, Val Loss: 0.6573, Train Acc: 0.9620, Val Acc:0.8703
# → Moyenne CV accuracy pour lr=0.001, bs=256 ,lamda=0.01 : 0.8735
# Testing Lamda=0.01 learning_rate=0.001, batch_size=512 ...
# Epoch 0, Train Loss: 2.6965, Val Loss: 1.8541, Train Acc: 0.4662, Val Acc:0.4603
# Epoch 10, Train Loss: 0.5190, Val Loss: 0.5908, Train Acc: 0.8607, Val Acc:0.8319
# Epoch 20, Train Loss: 0.3445, Val Loss: 0.5053, Train Acc: 0.9062, Val Acc:0.8617
# Epoch 30, Train Loss: 0.2660, Val Loss: 0.4786, Train Acc: 0.9269, Val Acc:0.8675
# Epoch 40, Train Loss: 0.2136, Val Loss: 0.4862, Train Acc: 0.9440, Val Acc:0.8726
# Epoch 50, Train Loss: 0.1823, Val Loss: 0.5114, Train Acc: 0.9493, Val Acc:0.8734
# Epoch 60, Train Loss: 0.1543, Val Loss: 0.5353, Train Acc: 0.9569, Val Acc:0.8739
# Epoch 70, Train Loss: 0.1268, Val Loss: 0.5653, Train Acc: 0.9634, Val Acc:0.8742
# Epoch 80, Train Loss: 0.1125, Val Loss: 0.5958, Train Acc: 0.9703, Val Acc:0.8726
# Epoch 90, Train Loss: 0.1111, Val Loss: 0.6431, Train Acc: 0.9700, Val Acc:0.8743
# Epoch 0, Train Loss: 2.6741, Val Loss: 1.9308, Train Acc: 0.4231, Val Acc:0.4160
# Epoch 10, Train Loss: 0.5419, Val Loss: 0.6238, Train Acc: 0.8629, Val Acc:0.8274
# Epoch 20, Train Loss: 0.3561, Val Loss: 0.5347, Train Acc: 0.9044, Val Acc:0.8521
# Epoch 30, Train Loss: 0.2773, Val Loss: 0.5190, Train Acc: 0.9249, Val Acc:0.8618
# Epoch 40, Train Loss: 0.2226, Val Loss: 0.5164, Train Acc: 0.9428, Val Acc:0.8672
# Epoch 50, Train Loss: 0.1830, Val Loss: 0.5525, Train Acc: 0.9475, Val Acc:0.8682
# Epoch 60, Train Loss: 0.1605, Val Loss: 0.5785, Train Acc: 0.9547, Val Acc:0.8689
# Epoch 70, Train Loss: 0.1402, Val Loss: 0.6088, Train Acc: 0.9587, Val Acc:0.8695
# Epoch 80, Train Loss: 0.1188, Val Loss: 0.6305, Train Acc: 0.9701, Val Acc:0.8699
# Epoch 90, Train Loss: 0.1052, Val Loss: 0.6718, Train Acc: 0.9705, Val Acc:0.8704
# Epoch 0, Train Loss: 2.6786, Val Loss: 1.8403, Train Acc: 0.4712, Val Acc:0.4707
# Epoch 10, Train Loss: 0.5356, Val Loss: 0.6061, Train Acc: 0.8611, Val Acc:0.8354
# Epoch 20, Train Loss: 0.3630, Val Loss: 0.5159, Train Acc: 0.9007, Val Acc:0.8581
# Epoch 30, Train Loss: 0.2756, Val Loss: 0.4709, Train Acc: 0.9289, Val Acc:0.8734
# Epoch 40, Train Loss: 0.2235, Val Loss: 0.4959, Train Acc: 0.9319, Val Acc:0.8732
# Epoch 50, Train Loss: 0.1856, Val Loss: 0.4869, Train Acc: 0.9532, Val Acc:0.8785
# Epoch 60, Train Loss: 0.1545, Val Loss: 0.5057, Train Acc: 0.9619, Val Acc:0.8811
# Epoch 70, Train Loss: 0.1340, Val Loss: 0.5458, Train Acc: 0.9629, Val Acc:0.8778
# Epoch 80, Train Loss: 0.1181, Val Loss: 0.6037, Train Acc: 0.9591, Val Acc:0.8711
# Epoch 90, Train Loss: 0.1040, Val Loss: 0.6070, Train Acc: 0.9714, Val Acc:0.8776
# Epoch 0, Train Loss: 2.6177, Val Loss: 1.7601, Train Acc: 0.4854, Val Acc:0.4824
# Epoch 10, Train Loss: 0.5246, Val Loss: 0.5873, Train Acc: 0.8565, Val Acc:0.8323
# Epoch 20, Train Loss: 0.3484, Val Loss: 0.4877, Train Acc: 0.9033, Val Acc:0.8617
# Epoch 30, Train Loss: 0.2656, Val Loss: 0.4596, Train Acc: 0.9272, Val Acc:0.8708
# Epoch 40, Train Loss: 0.2167, Val Loss: 0.4674, Train Acc: 0.9406, Val Acc:0.8766
# Epoch 50, Train Loss: 0.1805, Val Loss: 0.5068, Train Acc: 0.9388, Val Acc:0.8704
# Epoch 60, Train Loss: 0.1521, Val Loss: 0.5075, Train Acc: 0.9595, Val Acc:0.8785
# Epoch 70, Train Loss: 0.1307, Val Loss: 0.5438, Train Acc: 0.9604, Val Acc:0.8761
# Epoch 80, Train Loss: 0.1166, Val Loss: 0.5686, Train Acc: 0.9657, Val Acc:0.8791
# Epoch 90, Train Loss: 0.1069, Val Loss: 0.5965, Train Acc: 0.9740, Val Acc:0.8795
# Epoch 0, Train Loss: 2.6881, Val Loss: 1.8981, Train Acc: 0.4424, Val Acc:0.4411
# Epoch 10, Train Loss: 0.5438, Val Loss: 0.6090, Train Acc: 0.8553, Val Acc:0.8271
# Epoch 20, Train Loss: 0.3595, Val Loss: 0.5101, Train Acc: 0.9000, Val Acc:0.8572
# Epoch 30, Train Loss: 0.2772, Val Loss: 0.4845, Train Acc: 0.9226, Val Acc:0.8683
# Epoch 40, Train Loss: 0.2250, Val Loss: 0.4868, Train Acc: 0.9389, Val Acc:0.8717
# Epoch 50, Train Loss: 0.1778, Val Loss: 0.4963, Train Acc: 0.9523, Val Acc:0.8757
# Epoch 60, Train Loss: 0.1570, Val Loss: 0.5162, Train Acc: 0.9607, Val Acc:0.8756
# Epoch 70, Train Loss: 0.1322, Val Loss: 0.5831, Train Acc: 0.9527, Val Acc:0.8666
# Epoch 80, Train Loss: 0.1171, Val Loss: 0.6147, Train Acc: 0.9600, Val Acc:0.8681
# Epoch 90, Train Loss: 0.1069, Val Loss: 0.6212, Train Acc: 0.9730, Val Acc:0.8757
# → Moyenne CV accuracy pour lr=0.001, bs=512 ,lamda=0.01 : 0.8733
# Testing Lamda=0.01 learning_rate=0.01, batch_size=128 ...
# Epoch 0, Train Loss: 2.9138, Val Loss: 2.6323, Train Acc: 0.2496, Val Acc:0.2468
# Epoch 10, Train Loss: 2.2285, Val Loss: 2.2563, Train Acc: 0.3694, Val Acc:0.3617
# Epoch 20, Train Loss: 2.2053, Val Loss: 2.2032, Train Acc: 0.3946, Val Acc:0.3864
# Epoch 30, Train Loss: 2.2034, Val Loss: 2.2482, Train Acc: 0.3856, Val Acc:0.3771
# Epoch 40, Train Loss: 2.2058, Val Loss: 2.2465, Train Acc: 0.3840, Val Acc:0.3773
# Epoch 50, Train Loss: 2.2086, Val Loss: 2.2242, Train Acc: 0.3951, Val Acc:0.3841
# Epoch 60, Train Loss: 2.2017, Val Loss: 2.2008, Train Acc: 0.4016, Val Acc:0.3916
# Epoch 70, Train Loss: 2.1853, Val Loss: 2.3102, Train Acc: 0.3578, Val Acc:0.3527
# Epoch 80, Train Loss: 2.2056, Val Loss: 2.2491, Train Acc: 0.3840, Val Acc:0.3718
# Epoch 90, Train Loss: 2.1899, Val Loss: 2.2442, Train Acc: 0.3878, Val Acc:0.3804
# Epoch 0, Train Loss: 2.8637, Val Loss: 2.5981, Train Acc: 0.2821, Val Acc:0.2657
# Epoch 10, Train Loss: 2.2188, Val Loss: 2.2334, Train Acc: 0.3951, Val Acc:0.3707
# Epoch 20, Train Loss: 2.1954, Val Loss: 2.2367, Train Acc: 0.3962, Val Acc:0.3718
# Epoch 30, Train Loss: 2.2000, Val Loss: 2.2513, Train Acc: 0.3989, Val Acc:0.3775
# Epoch 40, Train Loss: 2.1699, Val Loss: 2.2213, Train Acc: 0.4029, Val Acc:0.3812
# Epoch 50, Train Loss: 2.1639, Val Loss: 2.2323, Train Acc: 0.4004, Val Acc:0.3793
# Epoch 60, Train Loss: 2.1715, Val Loss: 2.2296, Train Acc: 0.4038, Val Acc:0.3771
# Epoch 70, Train Loss: 2.1561, Val Loss: 2.2257, Train Acc: 0.4044, Val Acc:0.3809
# Epoch 80, Train Loss: 2.2172, Val Loss: 2.2259, Train Acc: 0.4009, Val Acc:0.3789
# Epoch 90, Train Loss: 2.1442, Val Loss: 2.2004, Train Acc: 0.4091, Val Acc:0.3867
# Epoch 0, Train Loss: 2.8542, Val Loss: 2.6126, Train Acc: 0.2386, Val Acc:0.2378
# Epoch 10, Train Loss: 2.2127, Val Loss: 2.2800, Train Acc: 0.3747, Val Acc:0.3699
# Epoch 20, Train Loss: 2.2184, Val Loss: 2.2627, Train Acc: 0.3818, Val Acc:0.3699
# Epoch 30, Train Loss: 2.1491, Val Loss: 2.1490, Train Acc: 0.4136, Val Acc:0.4021
# Epoch 40, Train Loss: 2.1237, Val Loss: 2.2113, Train Acc: 0.3918, Val Acc:0.3793
# Epoch 50, Train Loss: 2.1585, Val Loss: 2.2033, Train Acc: 0.3994, Val Acc:0.3850
# Epoch 60, Train Loss: 2.1234, Val Loss: 2.1072, Train Acc: 0.4285, Val Acc:0.4156
# Epoch 70, Train Loss: 2.1313, Val Loss: 2.1242, Train Acc: 0.4221, Val Acc:0.4089
# Epoch 80, Train Loss: 2.1375, Val Loss: 2.1784, Train Acc: 0.4047, Val Acc:0.3935
# Epoch 90, Train Loss: 2.1261, Val Loss: 2.1439, Train Acc: 0.4199, Val Acc:0.4067
# Epoch 0, Train Loss: 2.7651, Val Loss: 2.4469, Train Acc: 0.3025, Val Acc:0.2990
# Epoch 10, Train Loss: 2.1851, Val Loss: 2.2237, Train Acc: 0.3864, Val Acc:0.3775
# Epoch 20, Train Loss: 2.1525, Val Loss: 2.2007, Train Acc: 0.3825, Val Acc:0.3757
# Epoch 30, Train Loss: 2.1209, Val Loss: 2.1078, Train Acc: 0.4184, Val Acc:0.4115
# Epoch 40, Train Loss: 2.1110, Val Loss: 2.1558, Train Acc: 0.4030, Val Acc:0.3902
# Epoch 50, Train Loss: 2.1090, Val Loss: 2.1347, Train Acc: 0.4165, Val Acc:0.4043
# Epoch 60, Train Loss: 2.1164, Val Loss: 2.1381, Train Acc: 0.4076, Val Acc:0.4008
# Epoch 70, Train Loss: 2.1097, Val Loss: 2.1480, Train Acc: 0.4125, Val Acc:0.4026
# Epoch 80, Train Loss: 2.1038, Val Loss: 2.0842, Train Acc: 0.4281, Val Acc:0.4189
# Epoch 90, Train Loss: 2.1109, Val Loss: 2.1139, Train Acc: 0.4195, Val Acc:0.4128
# Epoch 0, Train Loss: 2.9818, Val Loss: 2.7998, Train Acc: 0.1643, Val Acc:0.1610
# Epoch 10, Train Loss: 2.2913, Val Loss: 2.4075, Train Acc: 0.3294, Val Acc:0.3212
# Epoch 20, Train Loss: 2.2205, Val Loss: 2.2853, Train Acc: 0.3761, Val Acc:0.3617
# Epoch 30, Train Loss: 2.2174, Val Loss: 2.4070, Train Acc: 0.3425, Val Acc:0.3304
# Epoch 40, Train Loss: 2.2471, Val Loss: 2.1806, Train Acc: 0.4016, Val Acc:0.3898
# Epoch 50, Train Loss: 2.2104, Val Loss: 2.2745, Train Acc: 0.3735, Val Acc:0.3614
# Epoch 60, Train Loss: 2.2062, Val Loss: 2.1879, Train Acc: 0.4007, Val Acc:0.3854
# Epoch 70, Train Loss: 2.1994, Val Loss: 2.2128, Train Acc: 0.3943, Val Acc:0.3818
# Epoch 80, Train Loss: 2.2039, Val Loss: 2.2378, Train Acc: 0.3908, Val Acc:0.3773
# Epoch 90, Train Loss: 2.2214, Val Loss: 2.2128, Train Acc: 0.3918, Val Acc:0.3848
# → Moyenne CV accuracy pour lr=0.01, bs=128 ,lamda=0.01 : 0.3893
# Testing Lamda=0.01 learning_rate=0.01, batch_size=256 ...
# Epoch 0, Train Loss: 2.6196, Val Loss: 2.2476, Train Acc: 0.3562, Val Acc:0.3498
# Epoch 10, Train Loss: 1.4342, Val Loss: 1.4975, Train Acc: 0.6052, Val Acc:0.5838
# Epoch 20, Train Loss: 2.6209, Val Loss: 2.2041, Train Acc: 0.3915, Val Acc:0.3810
# Epoch 30, Train Loss: 1.9952, Val Loss: 2.0738, Train Acc: 0.4509, Val Acc:0.4320
# Epoch 40, Train Loss: 2.0037, Val Loss: 2.0663, Train Acc: 0.4523, Val Acc:0.4329
# Epoch 50, Train Loss: 1.9960, Val Loss: 2.0637, Train Acc: 0.4554, Val Acc:0.4360
# Epoch 60, Train Loss: 1.9950, Val Loss: 2.0921, Train Acc: 0.4415, Val Acc:0.4238
# Epoch 70, Train Loss: 1.9960, Val Loss: 2.0849, Train Acc: 0.4472, Val Acc:0.4287
# Epoch 80, Train Loss: 2.0000, Val Loss: 2.0651, Train Acc: 0.4511, Val Acc:0.4324
# Epoch 90, Train Loss: 1.9842, Val Loss: 2.0838, Train Acc: 0.4486, Val Acc:0.4320
# Epoch 0, Train Loss: 2.1128, Val Loss: 1.6628, Train Acc: 0.5054, Val Acc:0.4927
# Epoch 10, Train Loss: 0.9871, Val Loss: 1.0713, Train Acc: 0.7125, Val Acc:0.6791
# Epoch 20, Train Loss: 0.8702, Val Loss: 0.9331, Train Acc: 0.7743, Val Acc:0.7267
# Epoch 30, Train Loss: 0.8377, Val Loss: 0.9964, Train Acc: 0.7561, Val Acc:0.7094
# Epoch 40, Train Loss: 0.8019, Val Loss: 1.1219, Train Acc: 0.7160, Val Acc:0.6752
# Epoch 50, Train Loss: 0.7865, Val Loss: 0.9646, Train Acc: 0.7640, Val Acc:0.7177
# Epoch 60, Train Loss: 0.7933, Val Loss: 1.0359, Train Acc: 0.7448, Val Acc:0.7025
# Epoch 70, Train Loss: 0.7466, Val Loss: 0.9423, Train Acc: 0.7751, Val Acc:0.7285
# Epoch 80, Train Loss: 0.7394, Val Loss: 0.9540, Train Acc: 0.7704, Val Acc:0.7241
# Epoch 90, Train Loss: 0.7278, Val Loss: 0.9574, Train Acc: 0.7697, Val Acc:0.7222
# Epoch 0, Train Loss: 2.9352, Val Loss: 2.4331, Train Acc: 0.2727, Val Acc:0.2720
# Epoch 10, Train Loss: 2.0533, Val Loss: 2.0854, Train Acc: 0.4404, Val Acc:0.4222
# Epoch 20, Train Loss: 2.0226, Val Loss: 2.1388, Train Acc: 0.4275, Val Acc:0.4104
# Epoch 30, Train Loss: 1.9865, Val Loss: 2.0434, Train Acc: 0.4540, Val Acc:0.4351
# Epoch 40, Train Loss: 1.9780, Val Loss: 2.0802, Train Acc: 0.4444, Val Acc:0.4284
# Epoch 50, Train Loss: 1.9776, Val Loss: 2.0511, Train Acc: 0.4510, Val Acc:0.4371
# Epoch 60, Train Loss: 1.9729, Val Loss: 2.0373, Train Acc: 0.4551, Val Acc:0.4379
# Epoch 70, Train Loss: 1.9883, Val Loss: 2.0487, Train Acc: 0.4557, Val Acc:0.4359
# Epoch 80, Train Loss: 2.1314, Val Loss: 2.1011, Train Acc: 0.4370, Val Acc:0.4205
# Epoch 90, Train Loss: 1.9696, Val Loss: 2.0309, Train Acc: 0.4597, Val Acc:0.4385
# Epoch 0, Train Loss: 2.5792, Val Loss: 2.2626, Train Acc: 0.3395, Val Acc:0.3380
# Epoch 10, Train Loss: 1.4518, Val Loss: 1.6174, Train Acc: 0.5735, Val Acc:0.5531
# Epoch 20, Train Loss: 1.4194, Val Loss: 1.4967, Train Acc: 0.6075, Val Acc:0.5805
# Epoch 30, Train Loss: 1.3968, Val Loss: 1.4724, Train Acc: 0.6180, Val Acc:0.5913
# Epoch 40, Train Loss: 1.9945, Val Loss: 2.0682, Train Acc: 0.4435, Val Acc:0.4272
# Epoch 50, Train Loss: 1.9879, Val Loss: 2.0645, Train Acc: 0.4417, Val Acc:0.4258
# Epoch 60, Train Loss: 1.9922, Val Loss: 2.0394, Train Acc: 0.4538, Val Acc:0.4371
# Epoch 70, Train Loss: 2.0025, Val Loss: 2.0721, Train Acc: 0.4383, Val Acc:0.4243
# Epoch 80, Train Loss: 1.9815, Val Loss: 2.0346, Train Acc: 0.4537, Val Acc:0.4376
# Epoch 90, Train Loss: 1.9736, Val Loss: 2.0260, Train Acc: 0.4557, Val Acc:0.4409
# Epoch 0, Train Loss: 2.2106, Val Loss: 1.7356, Train Acc: 0.4991, Val Acc:0.4907
# Epoch 10, Train Loss: 1.4034, Val Loss: 1.6010, Train Acc: 0.5695, Val Acc:0.5507
# Epoch 20, Train Loss: 2.0051, Val Loss: 2.0555, Train Acc: 0.4503, Val Acc:0.4309
# Epoch 30, Train Loss: 2.0037, Val Loss: 2.0980, Train Acc: 0.4371, Val Acc:0.4228
# Epoch 40, Train Loss: 1.9894, Val Loss: 2.1034, Train Acc: 0.4376, Val Acc:0.4156
# Epoch 50, Train Loss: 1.9686, Val Loss: 2.0590, Train Acc: 0.4493, Val Acc:0.4319
# Epoch 60, Train Loss: 1.9774, Val Loss: 2.0709, Train Acc: 0.4461, Val Acc:0.4236
# Epoch 70, Train Loss: 1.9750, Val Loss: 2.0736, Train Acc: 0.4451, Val Acc:0.4268
# Epoch 80, Train Loss: 1.9667, Val Loss: 2.0264, Train Acc: 0.4577, Val Acc:0.4413
# Epoch 90, Train Loss: 1.9820, Val Loss: 2.0275, Train Acc: 0.4592, Val Acc:0.4403
# → Moyenne CV accuracy pour lr=0.01, bs=256 ,lamda=0.01 : 0.4872
# Testing Lamda=0.01 learning_rate=0.01, batch_size=512 ...
# Epoch 0, Train Loss: 2.2048, Val Loss: 1.5722, Train Acc: 0.5388, Val Acc:0.5311
# Epoch 10, Train Loss: 0.8455, Val Loss: 0.9974, Train Acc: 0.7401, Val Acc:0.7072
# Epoch 20, Train Loss: 0.7179, Val Loss: 0.9481, Train Acc: 0.7525, Val Acc:0.7156
# Epoch 30, Train Loss: 0.7156, Val Loss: 0.9247, Train Acc: 0.7898, Val Acc:0.7400
# Epoch 40, Train Loss: 0.6582, Val Loss: 0.8846, Train Acc: 0.8001, Val Acc:0.7558
# Epoch 50, Train Loss: 0.6344, Val Loss: 1.0500, Train Acc: 0.7683, Val Acc:0.7259
# Epoch 60, Train Loss: 0.6161, Val Loss: 0.9666, Train Acc: 0.7855, Val Acc:0.7320
# Epoch 70, Train Loss: 0.5850, Val Loss: 0.8881, Train Acc: 0.8167, Val Acc:0.7619
# Epoch 80, Train Loss: 0.5643, Val Loss: 0.8713, Train Acc: 0.8239, Val Acc:0.7716
# Epoch 90, Train Loss: 0.5782, Val Loss: 0.9424, Train Acc: 0.8036, Val Acc:0.7549
# Epoch 0, Train Loss: 2.0212, Val Loss: 1.3864, Train Acc: 0.5764, Val Acc:0.5669
# Epoch 10, Train Loss: 0.7182, Val Loss: 1.0103, Train Acc: 0.7506, Val Acc:0.7111
# Epoch 20, Train Loss: 0.6542, Val Loss: 0.9041, Train Acc: 0.7998, Val Acc:0.7508
# Epoch 30, Train Loss: 0.5994, Val Loss: 0.8305, Train Acc: 0.8312, Val Acc:0.7769
# Epoch 40, Train Loss: 0.5481, Val Loss: 0.8423, Train Acc: 0.8423, Val Acc:0.7868
# Epoch 50, Train Loss: 0.5127, Val Loss: 0.8101, Train Acc: 0.8545, Val Acc:0.7911
# Epoch 60, Train Loss: 0.5473, Val Loss: 0.8494, Train Acc: 0.8483, Val Acc:0.7863
# Epoch 70, Train Loss: 0.5199, Val Loss: 0.8123, Train Acc: 0.8602, Val Acc:0.7959
# Epoch 80, Train Loss: 0.5007, Val Loss: 0.9371, Train Acc: 0.8316, Val Acc:0.7681
# Epoch 90, Train Loss: 0.5028, Val Loss: 0.9090, Train Acc: 0.8442, Val Acc:0.7808
# Epoch 0, Train Loss: 2.1806, Val Loss: 1.4414, Train Acc: 0.5664, Val Acc:0.5667
# Epoch 10, Train Loss: 0.7372, Val Loss: 0.8400, Train Acc: 0.7996, Val Acc:0.7615
# Epoch 20, Train Loss: 0.6572, Val Loss: 0.8552, Train Acc: 0.8156, Val Acc:0.7681
# Epoch 30, Train Loss: 0.5854, Val Loss: 0.9489, Train Acc: 0.7950, Val Acc:0.7498
# Epoch 40, Train Loss: 0.5684, Val Loss: 0.9044, Train Acc: 0.8239, Val Acc:0.7713
# Epoch 50, Train Loss: 0.5619, Val Loss: 0.8781, Train Acc: 0.8289, Val Acc:0.7715
# Epoch 60, Train Loss: 0.5335, Val Loss: 0.9377, Train Acc: 0.8186, Val Acc:0.7614
# Epoch 70, Train Loss: 0.5300, Val Loss: 0.8240, Train Acc: 0.8578, Val Acc:0.7939
# Epoch 80, Train Loss: 0.5055, Val Loss: 0.8633, Train Acc: 0.8526, Val Acc:0.7860
# Epoch 90, Train Loss: 0.5149, Val Loss: 0.8225, Train Acc: 0.8596, Val Acc:0.7930
# Epoch 0, Train Loss: 2.3061, Val Loss: 1.6928, Train Acc: 0.4786, Val Acc:0.4674
# Epoch 10, Train Loss: 0.8591, Val Loss: 1.0007, Train Acc: 0.7378, Val Acc:0.7048
# Epoch 20, Train Loss: 0.6910, Val Loss: 0.9094, Train Acc: 0.7871, Val Acc:0.7434
# Epoch 30, Train Loss: 0.6466, Val Loss: 0.9186, Train Acc: 0.7953, Val Acc:0.7401
# Epoch 40, Train Loss: 0.6162, Val Loss: 0.8413, Train Acc: 0.8332, Val Acc:0.7660
# Epoch 50, Train Loss: 0.6042, Val Loss: 0.8761, Train Acc: 0.8209, Val Acc:0.7580
# Epoch 60, Train Loss: 0.5777, Val Loss: 0.9194, Train Acc: 0.8117, Val Acc:0.7543
# Epoch 70, Train Loss: 0.5931, Val Loss: 0.9166, Train Acc: 0.8172, Val Acc:0.7524
# Epoch 80, Train Loss: 0.5365, Val Loss: 0.8164, Train Acc: 0.8589, Val Acc:0.7856
# Epoch 90, Train Loss: 0.5541, Val Loss: 0.8498, Train Acc: 0.8399, Val Acc:0.7744
# Epoch 0, Train Loss: 2.1590, Val Loss: 1.4160, Train Acc: 0.5762, Val Acc:0.5598
# Epoch 10, Train Loss: 0.7379, Val Loss: 0.9302, Train Acc: 0.7667, Val Acc:0.7297
# Epoch 20, Train Loss: 0.6285, Val Loss: 0.7959, Train Acc: 0.8254, Val Acc:0.7727
# Epoch 30, Train Loss: 0.5410, Val Loss: 0.7611, Train Acc: 0.8486, Val Acc:0.7901
# Epoch 40, Train Loss: 0.5745, Val Loss: 0.8443, Train Acc: 0.8282, Val Acc:0.7674
# Epoch 50, Train Loss: 0.5257, Val Loss: 0.8252, Train Acc: 0.8421, Val Acc:0.7831
# Epoch 60, Train Loss: 0.4979, Val Loss: 0.7695, Train Acc: 0.8563, Val Acc:0.7943
# Epoch 70, Train Loss: 0.5096, Val Loss: 0.8152, Train Acc: 0.8419, Val Acc:0.7798
# Epoch 80, Train Loss: 0.4561, Val Loss: 0.8833, Train Acc: 0.8417, Val Acc:0.7683
# Epoch 90, Train Loss: 0.4809, Val Loss: 0.8079, Train Acc: 0.8505, Val Acc:0.7829
# → Moyenne CV accuracy pour lr=0.01, bs=512 ,lamda=0.01 : 0.7864
# Testing Lamda=0.1 learning_rate=0.0001, batch_size=128 ...
# Epoch 0, Train Loss: 3.1431, Val Loss: 2.6565, Train Acc: 0.2343, Val Acc:0.2259
# Epoch 10, Train Loss: 1.0648, Val Loss: 1.0699, Train Acc: 0.7214, Val Acc:0.7106
# Epoch 20, Train Loss: 0.7685, Val Loss: 0.8180, Train Acc: 0.7986, Val Acc:0.7763
# Epoch 30, Train Loss: 0.6195, Val Loss: 0.6977, Train Acc: 0.8369, Val Acc:0.8113
# Epoch 40, Train Loss: 0.5297, Val Loss: 0.6252, Train Acc: 0.8627, Val Acc:0.8317
# Epoch 50, Train Loss: 0.4666, Val Loss: 0.5813, Train Acc: 0.8771, Val Acc:0.8421
# Epoch 60, Train Loss: 0.4198, Val Loss: 0.5457, Train Acc: 0.8909, Val Acc:0.8529
# Epoch 70, Train Loss: 0.3813, Val Loss: 0.5241, Train Acc: 0.9017, Val Acc:0.8580
# Epoch 80, Train Loss: 0.3507, Val Loss: 0.5066, Train Acc: 0.9115, Val Acc:0.8657
# Epoch 90, Train Loss: 0.3238, Val Loss: 0.4965, Train Acc: 0.9184, Val Acc:0.8677
# Epoch 0, Train Loss: 3.1505, Val Loss: 2.7035, Train Acc: 0.2317, Val Acc:0.2304
# Epoch 10, Train Loss: 1.0974, Val Loss: 1.1151, Train Acc: 0.7141, Val Acc:0.7018
# Epoch 20, Train Loss: 0.7507, Val Loss: 0.8160, Train Acc: 0.8039, Val Acc:0.7843
# Epoch 30, Train Loss: 0.6053, Val Loss: 0.6910, Train Acc: 0.8441, Val Acc:0.8149
# Epoch 40, Train Loss: 0.5186, Val Loss: 0.6233, Train Acc: 0.8663, Val Acc:0.8311
# Epoch 50, Train Loss: 0.4588, Val Loss: 0.5904, Train Acc: 0.8785, Val Acc:0.8379
# Epoch 60, Train Loss: 0.4127, Val Loss: 0.5575, Train Acc: 0.8956, Val Acc:0.8493
# Epoch 70, Train Loss: 0.3762, Val Loss: 0.5385, Train Acc: 0.9026, Val Acc:0.8549
# Epoch 80, Train Loss: 0.3475, Val Loss: 0.5182, Train Acc: 0.9111, Val Acc:0.8606
# Epoch 90, Train Loss: 0.3217, Val Loss: 0.5081, Train Acc: 0.9188, Val Acc:0.8632
# Epoch 0, Train Loss: 3.1226, Val Loss: 2.6531, Train Acc: 0.2297, Val Acc:0.2307
# Epoch 10, Train Loss: 1.0618, Val Loss: 1.0686, Train Acc: 0.7182, Val Acc:0.7114
# Epoch 20, Train Loss: 0.7770, Val Loss: 0.8289, Train Acc: 0.7946, Val Acc:0.7756
# Epoch 30, Train Loss: 0.6304, Val Loss: 0.7077, Train Acc: 0.8317, Val Acc:0.8068
# Epoch 40, Train Loss: 0.5376, Val Loss: 0.6339, Train Acc: 0.8562, Val Acc:0.8270
# Epoch 50, Train Loss: 0.4754, Val Loss: 0.5828, Train Acc: 0.8756, Val Acc:0.8411
# Epoch 60, Train Loss: 0.4259, Val Loss: 0.5557, Train Acc: 0.8901, Val Acc:0.8494
# Epoch 70, Train Loss: 0.3875, Val Loss: 0.5339, Train Acc: 0.8988, Val Acc:0.8535
# Epoch 80, Train Loss: 0.3575, Val Loss: 0.5167, Train Acc: 0.9088, Val Acc:0.8593
# Epoch 90, Train Loss: 0.3304, Val Loss: 0.5028, Train Acc: 0.9160, Val Acc:0.8647
# Epoch 0, Train Loss: 3.1204, Val Loss: 2.6275, Train Acc: 0.2520, Val Acc:0.2520
# Epoch 10, Train Loss: 1.0712, Val Loss: 1.0595, Train Acc: 0.7171, Val Acc:0.7035
# Epoch 20, Train Loss: 0.7678, Val Loss: 0.7877, Train Acc: 0.8005, Val Acc:0.7857
# Epoch 30, Train Loss: 0.6188, Val Loss: 0.6613, Train Acc: 0.8407, Val Acc:0.8190
# Epoch 40, Train Loss: 0.5259, Val Loss: 0.5869, Train Acc: 0.8655, Val Acc:0.8376
# Epoch 50, Train Loss: 0.4617, Val Loss: 0.5492, Train Acc: 0.8790, Val Acc:0.8488
# Epoch 60, Train Loss: 0.4126, Val Loss: 0.5213, Train Acc: 0.8919, Val Acc:0.8563
# Epoch 70, Train Loss: 0.3738, Val Loss: 0.4898, Train Acc: 0.9065, Val Acc:0.8626
# Epoch 80, Train Loss: 0.3441, Val Loss: 0.4859, Train Acc: 0.9099, Val Acc:0.8632
# Epoch 90, Train Loss: 0.3170, Val Loss: 0.4664, Train Acc: 0.9212, Val Acc:0.8703
# Epoch 0, Train Loss: 3.1393, Val Loss: 2.6708, Train Acc: 0.2330, Val Acc:0.2295
# Epoch 10, Train Loss: 1.1035, Val Loss: 1.1017, Train Acc: 0.7037, Val Acc:0.6934
# Epoch 20, Train Loss: 0.7833, Val Loss: 0.8212, Train Acc: 0.7904, Val Acc:0.7704
# Epoch 30, Train Loss: 0.6275, Val Loss: 0.6860, Train Acc: 0.8319, Val Acc:0.8109
# Epoch 40, Train Loss: 0.5315, Val Loss: 0.6153, Train Acc: 0.8596, Val Acc:0.8309
# Epoch 50, Train Loss: 0.4658, Val Loss: 0.5631, Train Acc: 0.8782, Val Acc:0.8432
# Epoch 60, Train Loss: 0.4169, Val Loss: 0.5348, Train Acc: 0.8903, Val Acc:0.8478
# Epoch 70, Train Loss: 0.3781, Val Loss: 0.5086, Train Acc: 0.9028, Val Acc:0.8567
# Epoch 80, Train Loss: 0.3468, Val Loss: 0.4909, Train Acc: 0.9118, Val Acc:0.8592
# Epoch 90, Train Loss: 0.3202, Val Loss: 0.4814, Train Acc: 0.9172, Val Acc:0.8632
# → Moyenne CV accuracy pour lr=0.0001, bs=128 ,lamda=0.1 : 0.8679
# Testing Lamda=0.1 learning_rate=0.0001, batch_size=256 ...
# Epoch 0, Train Loss: 3.3449, Val Loss: 2.9711, Train Acc: 0.1658, Val Acc:0.1608
# Epoch 10, Train Loss: 1.2838, Val Loss: 1.2744, Train Acc: 0.6578, Val Acc:0.6490
# Epoch 20, Train Loss: 0.9213, Val Loss: 0.9491, Train Acc: 0.7560, Val Acc:0.7425
# Epoch 30, Train Loss: 0.7549, Val Loss: 0.8076, Train Acc: 0.7985, Val Acc:0.7809
# Epoch 40, Train Loss: 0.6489, Val Loss: 0.7147, Train Acc: 0.8314, Val Acc:0.8107
# Epoch 50, Train Loss: 0.5744, Val Loss: 0.6596, Train Acc: 0.8484, Val Acc:0.8231
# Epoch 60, Train Loss: 0.5170, Val Loss: 0.6104, Train Acc: 0.8652, Val Acc:0.8388
# Epoch 70, Train Loss: 0.4708, Val Loss: 0.5772, Train Acc: 0.8763, Val Acc:0.8452
# Epoch 80, Train Loss: 0.4323, Val Loss: 0.5495, Train Acc: 0.8868, Val Acc:0.8521
# Epoch 90, Train Loss: 0.3999, Val Loss: 0.5267, Train Acc: 0.8963, Val Acc:0.8591
# Epoch 0, Train Loss: 3.3477, Val Loss: 2.9939, Train Acc: 0.1553, Val Acc:0.1524
# Epoch 10, Train Loss: 1.3083, Val Loss: 1.3139, Train Acc: 0.6525, Val Acc:0.6399
# Epoch 20, Train Loss: 0.9095, Val Loss: 0.9658, Train Acc: 0.7582, Val Acc:0.7442
# Epoch 30, Train Loss: 0.7370, Val Loss: 0.8120, Train Acc: 0.8065, Val Acc:0.7827
# Epoch 40, Train Loss: 0.6274, Val Loss: 0.7210, Train Acc: 0.8362, Val Acc:0.8082
# Epoch 50, Train Loss: 0.5502, Val Loss: 0.6633, Train Acc: 0.8540, Val Acc:0.8220
# Epoch 60, Train Loss: 0.4921, Val Loss: 0.6217, Train Acc: 0.8712, Val Acc:0.8357
# Epoch 70, Train Loss: 0.4461, Val Loss: 0.5892, Train Acc: 0.8794, Val Acc:0.8404
# Epoch 80, Train Loss: 0.4090, Val Loss: 0.5651, Train Acc: 0.8906, Val Acc:0.8482
# Epoch 90, Train Loss: 0.3788, Val Loss: 0.5462, Train Acc: 0.9006, Val Acc:0.8531
# Epoch 0, Train Loss: 3.3417, Val Loss: 2.9583, Train Acc: 0.1638, Val Acc:0.1636
# Epoch 10, Train Loss: 1.2687, Val Loss: 1.2503, Train Acc: 0.6629, Val Acc:0.6600
# Epoch 20, Train Loss: 0.9137, Val Loss: 0.9455, Train Acc: 0.7580, Val Acc:0.7461
# Epoch 30, Train Loss: 0.7474, Val Loss: 0.8042, Train Acc: 0.8030, Val Acc:0.7821
# Epoch 40, Train Loss: 0.6444, Val Loss: 0.7192, Train Acc: 0.8300, Val Acc:0.8056
# Epoch 50, Train Loss: 0.5713, Val Loss: 0.6648, Train Acc: 0.8481, Val Acc:0.8179
# Epoch 60, Train Loss: 0.5143, Val Loss: 0.6217, Train Acc: 0.8643, Val Acc:0.8317
# Epoch 70, Train Loss: 0.4700, Val Loss: 0.5872, Train Acc: 0.8789, Val Acc:0.8413
# Epoch 80, Train Loss: 0.4326, Val Loss: 0.5671, Train Acc: 0.8878, Val Acc:0.8479
# Epoch 90, Train Loss: 0.4012, Val Loss: 0.5412, Train Acc: 0.8963, Val Acc:0.8553
# Epoch 0, Train Loss: 3.3369, Val Loss: 2.9430, Train Acc: 0.1712, Val Acc:0.1725
# Epoch 10, Train Loss: 1.2844, Val Loss: 1.2597, Train Acc: 0.6563, Val Acc:0.6460
# Epoch 20, Train Loss: 0.9247, Val Loss: 0.9322, Train Acc: 0.7549, Val Acc:0.7394
# Epoch 30, Train Loss: 0.7532, Val Loss: 0.7763, Train Acc: 0.8028, Val Acc:0.7895
# Epoch 40, Train Loss: 0.6419, Val Loss: 0.6841, Train Acc: 0.8326, Val Acc:0.8152
# Epoch 50, Train Loss: 0.5649, Val Loss: 0.6228, Train Acc: 0.8531, Val Acc:0.8305
# Epoch 60, Train Loss: 0.5059, Val Loss: 0.5811, Train Acc: 0.8670, Val Acc:0.8415
# Epoch 70, Train Loss: 0.4594, Val Loss: 0.5516, Train Acc: 0.8802, Val Acc:0.8499
# Epoch 80, Train Loss: 0.4234, Val Loss: 0.5316, Train Acc: 0.8888, Val Acc:0.8545
# Epoch 90, Train Loss: 0.3911, Val Loss: 0.5102, Train Acc: 0.8987, Val Acc:0.8611
# Epoch 0, Train Loss: 3.3414, Val Loss: 2.9831, Train Acc: 0.1612, Val Acc:0.1588
# Epoch 10, Train Loss: 1.2339, Val Loss: 1.2202, Train Acc: 0.6698, Val Acc:0.6605
# Epoch 20, Train Loss: 0.8960, Val Loss: 0.9202, Train Acc: 0.7598, Val Acc:0.7470
# Epoch 30, Train Loss: 0.7385, Val Loss: 0.7845, Train Acc: 0.8019, Val Acc:0.7835
# Epoch 40, Train Loss: 0.6364, Val Loss: 0.6955, Train Acc: 0.8312, Val Acc:0.8118
# Epoch 50, Train Loss: 0.5630, Val Loss: 0.6357, Train Acc: 0.8504, Val Acc:0.8240
# Epoch 60, Train Loss: 0.5073, Val Loss: 0.5971, Train Acc: 0.8660, Val Acc:0.8320
# Epoch 70, Train Loss: 0.4638, Val Loss: 0.5630, Train Acc: 0.8773, Val Acc:0.8468
# Epoch 80, Train Loss: 0.4273, Val Loss: 0.5387, Train Acc: 0.8872, Val Acc:0.8509
# Epoch 90, Train Loss: 0.3967, Val Loss: 0.5258, Train Acc: 0.8925, Val Acc:0.8547
# → Moyenne CV accuracy pour lr=0.0001, bs=256 ,lamda=0.1 : 0.8597
# Testing Lamda=0.1 learning_rate=0.0001, batch_size=512 ...
# Epoch 0, Train Loss: 3.4884, Val Loss: 3.3349, Train Acc: 0.0935, Val Acc:0.0938
# Epoch 10, Train Loss: 1.5659, Val Loss: 1.5409, Train Acc: 0.5729, Val Acc:0.5653
# Epoch 20, Train Loss: 1.0966, Val Loss: 1.1086, Train Acc: 0.7073, Val Acc:0.6961
# Epoch 30, Train Loss: 0.8950, Val Loss: 0.9281, Train Acc: 0.7622, Val Acc:0.7472
# Epoch 40, Train Loss: 0.7723, Val Loss: 0.8253, Train Acc: 0.7933, Val Acc:0.7759
# Epoch 50, Train Loss: 0.6869, Val Loss: 0.7522, Train Acc: 0.8178, Val Acc:0.7962
# Epoch 60, Train Loss: 0.6213, Val Loss: 0.6993, Train Acc: 0.8366, Val Acc:0.8129
# Epoch 70, Train Loss: 0.5692, Val Loss: 0.6598, Train Acc: 0.8476, Val Acc:0.8231
# Epoch 80, Train Loss: 0.5274, Val Loss: 0.6254, Train Acc: 0.8598, Val Acc:0.8316
# Epoch 90, Train Loss: 0.4921, Val Loss: 0.5980, Train Acc: 0.8700, Val Acc:0.8382
# Epoch 0, Train Loss: 3.4875, Val Loss: 3.3286, Train Acc: 0.0926, Val Acc:0.0929
# Epoch 10, Train Loss: 1.6213, Val Loss: 1.6035, Train Acc: 0.5586, Val Acc:0.5536
# Epoch 20, Train Loss: 1.1247, Val Loss: 1.1552, Train Acc: 0.6974, Val Acc:0.6844
# Epoch 30, Train Loss: 0.9115, Val Loss: 0.9639, Train Acc: 0.7548, Val Acc:0.7384
# Epoch 40, Train Loss: 0.7856, Val Loss: 0.8562, Train Acc: 0.7925, Val Acc:0.7717
# Epoch 50, Train Loss: 0.6981, Val Loss: 0.7866, Train Acc: 0.8139, Val Acc:0.7885
# Epoch 60, Train Loss: 0.6314, Val Loss: 0.7335, Train Acc: 0.8313, Val Acc:0.8034
# Epoch 70, Train Loss: 0.5777, Val Loss: 0.6893, Train Acc: 0.8475, Val Acc:0.8133
# Epoch 80, Train Loss: 0.5338, Val Loss: 0.6556, Train Acc: 0.8575, Val Acc:0.8227
# Epoch 90, Train Loss: 0.4970, Val Loss: 0.6288, Train Acc: 0.8691, Val Acc:0.8304
# Epoch 0, Train Loss: 3.4901, Val Loss: 3.3382, Train Acc: 0.0912, Val Acc:0.0916
# Epoch 10, Train Loss: 1.5199, Val Loss: 1.4776, Train Acc: 0.5970, Val Acc:0.5977
# Epoch 20, Train Loss: 1.0712, Val Loss: 1.0828, Train Acc: 0.7125, Val Acc:0.7095
# Epoch 30, Train Loss: 0.8819, Val Loss: 0.9159, Train Acc: 0.7645, Val Acc:0.7546
# Epoch 40, Train Loss: 0.7659, Val Loss: 0.8181, Train Acc: 0.7963, Val Acc:0.7783
# Epoch 50, Train Loss: 0.6841, Val Loss: 0.7458, Train Acc: 0.8185, Val Acc:0.8000
# Epoch 60, Train Loss: 0.6219, Val Loss: 0.6977, Train Acc: 0.8353, Val Acc:0.8109
# Epoch 70, Train Loss: 0.5726, Val Loss: 0.6581, Train Acc: 0.8473, Val Acc:0.8203
# Epoch 80, Train Loss: 0.5308, Val Loss: 0.6249, Train Acc: 0.8607, Val Acc:0.8316
# Epoch 90, Train Loss: 0.4939, Val Loss: 0.5964, Train Acc: 0.8693, Val Acc:0.8391
# Epoch 0, Train Loss: 3.4893, Val Loss: 3.3297, Train Acc: 0.0897, Val Acc:0.0888
# Epoch 10, Train Loss: 1.5627, Val Loss: 1.5218, Train Acc: 0.5797, Val Acc:0.5695
# Epoch 20, Train Loss: 1.1179, Val Loss: 1.1116, Train Acc: 0.7006, Val Acc:0.6879
# Epoch 30, Train Loss: 0.9154, Val Loss: 0.9285, Train Acc: 0.7574, Val Acc:0.7424
# Epoch 40, Train Loss: 0.7947, Val Loss: 0.8215, Train Acc: 0.7899, Val Acc:0.7758
# Epoch 50, Train Loss: 0.7074, Val Loss: 0.7455, Train Acc: 0.8121, Val Acc:0.7955
# Epoch 60, Train Loss: 0.6398, Val Loss: 0.6905, Train Acc: 0.8301, Val Acc:0.8105
# Epoch 70, Train Loss: 0.5862, Val Loss: 0.6450, Train Acc: 0.8442, Val Acc:0.8246
# Epoch 80, Train Loss: 0.5426, Val Loss: 0.6130, Train Acc: 0.8569, Val Acc:0.8327
# Epoch 90, Train Loss: 0.5060, Val Loss: 0.5865, Train Acc: 0.8656, Val Acc:0.8424
# Epoch 0, Train Loss: 3.4871, Val Loss: 3.3322, Train Acc: 0.0907, Val Acc:0.0876
# Epoch 10, Train Loss: 1.5270, Val Loss: 1.4944, Train Acc: 0.5889, Val Acc:0.5763
# Epoch 20, Train Loss: 1.0870, Val Loss: 1.0865, Train Acc: 0.7094, Val Acc:0.7001
# Epoch 30, Train Loss: 0.8922, Val Loss: 0.9160, Train Acc: 0.7623, Val Acc:0.7479
# Epoch 40, Train Loss: 0.7735, Val Loss: 0.8114, Train Acc: 0.7944, Val Acc:0.7751
# Epoch 50, Train Loss: 0.6875, Val Loss: 0.7361, Train Acc: 0.8168, Val Acc:0.7980
# Epoch 60, Train Loss: 0.6219, Val Loss: 0.6827, Train Acc: 0.8346, Val Acc:0.8137
# Epoch 70, Train Loss: 0.5705, Val Loss: 0.6404, Train Acc: 0.8485, Val Acc:0.8247
# Epoch 80, Train Loss: 0.5280, Val Loss: 0.6079, Train Acc: 0.8600, Val Acc:0.8304
# Epoch 90, Train Loss: 0.4928, Val Loss: 0.5854, Train Acc: 0.8681, Val Acc:0.8371
# → Moyenne CV accuracy pour lr=0.0001, bs=512 ,lamda=0.1 : 0.8420
# Testing Lamda=0.1 learning_rate=0.001, batch_size=128 ...
# Epoch 0, Train Loss: 2.0312, Val Loss: 1.2757, Train Acc: 0.6449, Val Acc:0.6357
# Epoch 10, Train Loss: 0.4735, Val Loss: 0.5529, Train Acc: 0.8731, Val Acc:0.8441
# Epoch 20, Train Loss: 0.3862, Val Loss: 0.5081, Train Acc: 0.8898, Val Acc:0.8555
# Epoch 30, Train Loss: 0.3356, Val Loss: 0.4637, Train Acc: 0.9059, Val Acc:0.8647
# Epoch 40, Train Loss: 0.3228, Val Loss: 0.4877, Train Acc: 0.8966, Val Acc:0.8549
# Epoch 50, Train Loss: 0.3077, Val Loss: 0.4749, Train Acc: 0.9019, Val Acc:0.8644
# Epoch 60, Train Loss: 0.3006, Val Loss: 0.4477, Train Acc: 0.9124, Val Acc:0.8730
# Epoch 70, Train Loss: 0.2893, Val Loss: 0.4356, Train Acc: 0.9183, Val Acc:0.8787
# Epoch 80, Train Loss: 0.2856, Val Loss: 0.4789, Train Acc: 0.9061, Val Acc:0.8639
# Epoch 90, Train Loss: 0.2834, Val Loss: 0.4270, Train Acc: 0.9212, Val Acc:0.8782
# Epoch 0, Train Loss: 2.0908, Val Loss: 1.3470, Train Acc: 0.6201, Val Acc:0.6149
# Epoch 10, Train Loss: 0.4775, Val Loss: 0.5827, Train Acc: 0.8677, Val Acc:0.8326
# Epoch 20, Train Loss: 0.3827, Val Loss: 0.5539, Train Acc: 0.8845, Val Acc:0.8412
# Epoch 30, Train Loss: 0.3541, Val Loss: 0.5384, Train Acc: 0.8931, Val Acc:0.8456
# Epoch 40, Train Loss: 0.3317, Val Loss: 0.4995, Train Acc: 0.9024, Val Acc:0.8549
# Epoch 50, Train Loss: 0.3143, Val Loss: 0.4945, Train Acc: 0.9059, Val Acc:0.8542
# Epoch 60, Train Loss: 0.3127, Val Loss: 0.4741, Train Acc: 0.9147, Val Acc:0.8639
# Epoch 70, Train Loss: 0.3055, Val Loss: 0.4754, Train Acc: 0.9121, Val Acc:0.8637
# Epoch 80, Train Loss: 0.3049, Val Loss: 0.5246, Train Acc: 0.8990, Val Acc:0.8506
# Epoch 90, Train Loss: 0.2980, Val Loss: 0.4907, Train Acc: 0.9073, Val Acc:0.8593
# Epoch 0, Train Loss: 2.1044, Val Loss: 1.3465, Train Acc: 0.6195, Val Acc:0.6085
# Epoch 10, Train Loss: 0.4729, Val Loss: 0.5902, Train Acc: 0.8618, Val Acc:0.8286
# Epoch 20, Train Loss: 0.3853, Val Loss: 0.5536, Train Acc: 0.8800, Val Acc:0.8451
# Epoch 30, Train Loss: 0.3525, Val Loss: 0.5314, Train Acc: 0.8827, Val Acc:0.8493
# Epoch 40, Train Loss: 0.3313, Val Loss: 0.4757, Train Acc: 0.9063, Val Acc:0.8645
# Epoch 50, Train Loss: 0.3154, Val Loss: 0.4627, Train Acc: 0.9107, Val Acc:0.8694
# Epoch 60, Train Loss: 0.3035, Val Loss: 0.4651, Train Acc: 0.9096, Val Acc:0.8655
# Epoch 70, Train Loss: 0.2947, Val Loss: 0.4629, Train Acc: 0.9100, Val Acc:0.8680
# Epoch 80, Train Loss: 0.3020, Val Loss: 0.4419, Train Acc: 0.9187, Val Acc:0.8745
# Epoch 90, Train Loss: 0.2828, Val Loss: 0.4394, Train Acc: 0.9142, Val Acc:0.8723
# Epoch 0, Train Loss: 1.9679, Val Loss: 1.2372, Train Acc: 0.6553, Val Acc:0.6432
# Epoch 10, Train Loss: 0.4812, Val Loss: 0.6094, Train Acc: 0.8436, Val Acc:0.8155
# Epoch 20, Train Loss: 0.3796, Val Loss: 0.4725, Train Acc: 0.8994, Val Acc:0.8601
# Epoch 30, Train Loss: 0.3486, Val Loss: 0.4874, Train Acc: 0.8937, Val Acc:0.8529
# Epoch 40, Train Loss: 0.3254, Val Loss: 0.4556, Train Acc: 0.9068, Val Acc:0.8668
# Epoch 50, Train Loss: 0.3238, Val Loss: 0.4574, Train Acc: 0.9044, Val Acc:0.8650
# Epoch 60, Train Loss: 0.3045, Val Loss: 0.5068, Train Acc: 0.8901, Val Acc:0.8473
# Epoch 70, Train Loss: 0.2935, Val Loss: 0.4229, Train Acc: 0.9201, Val Acc:0.8764
# Epoch 80, Train Loss: 0.2939, Val Loss: 0.4574, Train Acc: 0.9030, Val Acc:0.8644
# Epoch 90, Train Loss: 0.2858, Val Loss: 0.4248, Train Acc: 0.9176, Val Acc:0.8732
# Epoch 0, Train Loss: 2.0961, Val Loss: 1.3396, Train Acc: 0.6201, Val Acc:0.6151
# Epoch 10, Train Loss: 0.5017, Val Loss: 0.5931, Train Acc: 0.8586, Val Acc:0.8309
# Epoch 20, Train Loss: 0.4095, Val Loss: 0.5003, Train Acc: 0.8915, Val Acc:0.8579
# Epoch 30, Train Loss: 0.3626, Val Loss: 0.4937, Train Acc: 0.8917, Val Acc:0.8545
# Epoch 40, Train Loss: 0.3442, Val Loss: 0.4456, Train Acc: 0.9109, Val Acc:0.8659
# Epoch 50, Train Loss: 0.3224, Val Loss: 0.4509, Train Acc: 0.9137, Val Acc:0.8695
# Epoch 60, Train Loss: 0.3129, Val Loss: 0.5186, Train Acc: 0.8918, Val Acc:0.8453
# Epoch 70, Train Loss: 0.3047, Val Loss: 0.4558, Train Acc: 0.9108, Val Acc:0.8664
# Epoch 80, Train Loss: 0.2989, Val Loss: 0.4421, Train Acc: 0.9150, Val Acc:0.8735
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 40
#      37 nn = MultiClassNeuralNetwork(layer_sizes, model_optimization="Adam",lamda=lm,learning_rate=lr)
#      39 # Entraîner sur ce fold
# ---> 40 _, val_losses, _, val_accs = nn.train(
#      41     X_train_fold, y_train_fold,
#      42     X_val_fold,   y_val_fold,
#      43     epochs=100, batch_size=bs
#      44 )
#      46 # Récupérer la dernière accuracy du fold de validation
#      47 fold_accuracies.append(val_accs[-1])
#
# Cell In[45], line 196, in MultiClassNeuralNetwork.train(self, X, y, X_val, y_val, epochs, batch_size)
#     193 X_batch = X_shuffled[i:i+batch_size]
#     194 y_batch = y_shuffled[i:i+batch_size]
# --> 196 outputs = self.forward(X_batch)
#     197 epoch_loss += self.compute_loss(y_batch , outputs)
#     198 self.backward(X_batch , y_batch , outputs)
#
# Cell In[45], line 51, in MultiClassNeuralNetwork.forward(self, X)
#      48 self.z_values = []
#      50 for i in range(len(self.weights) - 1):
# ---> 51     z = np.dot(self.activations[-1],self.weights[i])+self.biases[i]
#      52     assert z.shape == (X.shape[0], self.layer_sizes[i+1]),f"Z^{[i+1]} has incorrect shape"
#      53     self.z_values.append(z)
#
# KeyboardInterrupt:
